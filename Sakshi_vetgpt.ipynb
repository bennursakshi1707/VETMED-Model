# %%
import glob
import math
import sys
import time
from pathlib import Path
from typing import Optional, Tuple, Union
import torch
from torch.utils.data import DataLoader
from functools import partial
import lightning as L
from lightning.fabric.strategies import FSDPStrategy, XLAStrategy
from lit_gpt.model import GPT, Block, Config, CausalSelfAttention
from lit_gpt.packed_dataset import CombinedDataset, PackedDataset
from lit_gpt.speed_monitor import SpeedMonitorFabric as Monitor
from lit_gpt.speed_monitor import estimate_flops, measure_flops
from lit_gpt.utils import chunked_cross_entropy, get_default_supported_precision, num_parameters, step_csv_logger, lazy_load
from pytorch_lightning.loggers import WandbLogger
from lit_gpt import FusedCrossEntropyLoss
import random

# %%
model_name = "VetMed_Model"
name = "test"
out_dir = Path("out") / name
checkpoint_path = "/scratch/vetgpt/out/first_pretrain_version/vetmedgpt-v0.2.pth"

num_of_devices = 6
global_batch_size = 480
learning_rate = 4e-4
micro_batch_size = 20
max_step = 500000
warmup_steps = 2000
log_step_interval = 1
eval_iters = 100
save_step_interval = 5000
eval_step_interval = 5000

weight_decay = 1e-1
beta1 = 0.9
beta2 = 0.95
grad_clip = 1.0
decay_lr = True
min_lr = 4e-5

batch_size = global_batch_size // num_of_devices
gradient_accumulation_steps = batch_size // micro_batch_size
assert gradient_accumulation_steps > 0
warmup_iters = warmup_steps * gradient_accumulation_steps

max_iters = max_step * gradient_accumulation_steps
lr_decay_iters = max_iters
log_iter_interval = log_step_interval * gradient_accumulation_steps

# Treat all dataset equally by their size. If you want to use a different weight for a dataset, add it to the list with the weight.
train_data_config = [
    ("train_vetdata2", 1.0),
]

val_data_config = [
    ("train_vetdata2", 1.0),
]

hparams = {k: v for k, v in locals().items() if isinstance(v, (int, float, str)) and not k.startswith("_")}
logger = step_csv_logger("out", name, flush_logs_every_n_steps=log_iter_interval)
# wandb_logger = WandbLogger()

def setup(
    devices: int = num_of_devices,
    train_data_dir: Path = Path(""),
    val_data_dir: Optional[Path] = None,
    precision: Optional[str] = None,
    tpu: bool = False,
    resume: Union[bool, Path] = False,
) -> None:
    precision = precision or get_default_supported_precision(training=True, tpu=tpu)

    if devices > 1:
        if tpu:
            # For multi-host TPU training, the device count for Fabric is limited to the count on a single host.
            devices = "auto"
            strategy = XLAStrategy(sync_module_states=False)
        else:
            strategy = FSDPStrategy(
                auto_wrap_policy={Block},
                activation_checkpointing_policy=None,
                state_dict_type="full",
                limit_all_gathers=True,
                cpu_offload=False,
            )
    else:
        strategy = "auto"

    fabric = L.Fabric(devices=devices, strategy=strategy, precision=precision, loggers=[logger])
    fabric.print(hparams)
    # fabric.launch(main, train_data_dir, val_data_dir, resume)
    main(fabric, train_data_dir, val_data_dir, resume)

def main(fabric, train_data_dir, val_data_dir, resume):
    monitor = Monitor(fabric, window_size=2, time_unit="seconds", log_iter_interval=log_iter_interval)

    if fabric.global_rank == 0:
        out_dir.mkdir(parents=True, exist_ok=True)

    config = Config.from_name(model_name)

    train_dataloader, val_dataloader = create_dataloaders(
        batch_size=micro_batch_size,
        block_size=config.block_size,
        fabric=fabric,
        train_data_dir=train_data_dir,
        val_data_dir=val_data_dir,
        seed=3407,
    )
    if val_dataloader is None:
        train_dataloader = fabric.setup_dataloaders(train_dataloader)
    else:
        train_dataloader, val_dataloader = fabric.setup_dataloaders(train_dataloader, val_dataloader)

    fabric.seed_everything(3407)  # same seed for every process to init model (FSDP)

    fabric.print(f"Loading model with {config.__dict__}")
    t0 = time.perf_counter()
    with fabric.init_module(empty_init=False):
        model = GPT(config)
        model.apply(partial(model._init_weights, n_layer=config.n_layer))

    fabric.print(f"Time to instantiate model: {time.perf_counter() - t0:.02f} seconds.")
    fabric.print(f"Total parameters {num_parameters(model):,}")

    model = fabric.setup(model)
    fabric.load_raw(checkpoint_path, model, strict=True)
    optimizer = torch.optim.AdamW(
        model.parameters(), lr=learning_rate, weight_decay=weight_decay, betas=(beta1, beta2), foreach=False
    )
    # optimizer = FusedAdam(model.parameters(), lr=learning_rate, weight_decay=weight_decay, betas=(beta1, beta2), adam_w_mode=True)
    optimizer = fabric.setup_optimizers(optimizer)

    state = {"model": model, "optimizer": optimizer, "hparams": hparams, "iter_num": 0, "step_count": 0}

    if resume is True:
        resume = sorted(out_dir.glob("*.pth"))[-1]
    if resume:
        fabric.print(f"Resuming training from {resume}")
        fabric.load(resume, state)

    train_time = time.perf_counter()
    train(fabric, state, train_dataloader, val_dataloader, monitor, resume)
    fabric.print(f"Training time: {(time.perf_counter() - train_time):.2f}s")
    if fabric.device.type == "cuda":
        fabric.print(f"Memory used: {torch.cuda.max_memory_allocated() / 1e9:.02f} GB")

def train(fabric, state, train_dataloader, val_dataloader, monitor, resume):
    model = state["model"]
    optimizer = state["optimizer"]

    if val_dataloader is not None:
        validate(fabric, model, val_dataloader)  # sanity check

    with torch.device("meta"):
        meta_model = GPT(model.config)
        # "estimated" is not as precise as "measured". Estimated is optimistic but widely used in the wild.
        estimated_flops = estimate_flops(meta_model) * micro_batch_size
        fabric.print(f"Estimated TFLOPs: {estimated_flops * fabric.world_size / 1e12:.2f}")
        x = torch.randint(0, 1, (micro_batch_size, model.config.block_size))
        del meta_model, x

    total_lengths = 0
    total_t0 = time.perf_counter()

    if fabric.device.type == "xla":
        import torch_xla.core.xla_model as xm
        xm.mark_step()
    
    initial_iter = state["iter_num"]
    curr_iter = 0
            
    loss_func = FusedCrossEntropyLoss()
    for train_data in train_dataloader:
        if resume:
            if curr_iter < initial_iter:
                curr_iter += 1
                continue
            else:
                resume = False
                curr_iter = -1
                fabric.barrier()
                fabric.print("resume finished, taken {} seconds".format(time.perf_counter() - total_t0))
        if state["iter_num"] >= max_iters:
            break
        
        lr = get_lr(state["iter_num"]) if decay_lr else learning_rate
        for param_group in optimizer.param_groups:
            param_group["lr"] = lr

        iter_t0 = time.perf_counter()

        input_ids = train_data[:, 0 : model.config.block_size].contiguous()
        targets = train_data[:, 1 : model.config.block_size + 1].contiguous()
        is_accumulating = (state["iter_num"] + 1) % gradient_accumulation_steps != 0
        with fabric.no_backward_sync(model, enabled=is_accumulating):
            logits = model(input_ids)
            loss = loss_func(logits, targets)
            fabric.backward(loss / gradient_accumulation_steps)

        if not is_accumulating:
            fabric.clip_gradients(model, optimizer, max_norm=grad_clip)
            optimizer.step()
            optimizer.zero_grad()
            state["step_count"] += 1
        elif fabric.device.type == "xla":
            xm.mark_step()
        state["iter_num"] += 1
        total_lengths += input_ids.size(1)
        t1 = time.perf_counter()
        fabric.print(
                f"iter {state['iter_num']} step {state['step_count']}: loss {loss.item():.4f}, iter time:"
                f" {(t1 - iter_t0) * 1000:.2f}ms{' (optimizer.step)' if not is_accumulating else ''}"
                f" remaining time: {(t1 - total_t0) / (state['iter_num'] - initial_iter) * (max_iters - state['iter_num']) / 3600:.2f} hours. " 
                f" or {(t1 - total_t0) / (state['iter_num'] - initial_iter) * (max_iters - state['iter_num']) / 3600 / 24:.2f} days. "
            )
 
        monitor.on_train_batch_end(
            state["iter_num"] * micro_batch_size,
            t1 - total_t0,
            fabric.world_size,
            state["step_count"],
            flops_per_batch=estimated_flops,
            lengths=total_lengths,
            train_loss=loss.item()
        )
            
        if val_dataloader is not None and not is_accumulating and state["step_count"] % eval_step_interval == 0:
            t0 = time.perf_counter()
            val_loss = validate(fabric, model, val_dataloader)
            t1 = time.perf_counter() - t0
            monitor.eval_end(t1)
            fabric.print(f"step {state['iter_num']}: val loss {val_loss:.4f}, val time: {t1 * 1000:.2f}ms")
            fabric.log_dict({"metric/val_loss": val_loss.item(), "total_tokens": model.config.block_size * (state["iter_num"] + 1) * micro_batch_size * fabric.world_size}, state["step_count"])
            fabric.log_dict({"metric/val_ppl": math.exp(val_loss.item()), "total_tokens": model.config.block_size * (state["iter_num"] + 1) * micro_batch_size * fabric.world_size}, state["step_count"])
            fabric.barrier()
        if not is_accumulating and state["step_count"] % save_step_interval == 0:
            checkpoint_path = out_dir / f"iter-{state['iter_num']:06d}-ckpt.pth"
            fabric.print(f"Saving checkpoint to {str(checkpoint_path)!r}")
            fabric.save(checkpoint_path, state)

@torch.no_grad()
def validate(fabric: L.Fabric, model: torch.nn.Module, val_dataloader: DataLoader) -> torch.Tensor:
    fabric.print("Validating ...")
    model.eval()

    losses = torch.zeros(eval_iters, device=fabric.device)
    for k, val_data in enumerate(val_dataloader):
        if k >= eval_iters:
            break
        input_ids = val_data[:, 0 : model.config.block_size].contiguous()
        targets = val_data[:, 1 : model.config.block_size + 1].contiguous()
        logits = model(input_ids)
        loss = chunked_cross_entropy(logits, targets, chunk_size=0)
        losses[k] = loss.item()
        
    out = losses.mean()
    model.train()
    return out

def create_dataloader(
    batch_size: int, block_size: int, data_dir: Path, fabric, shuffle: bool = True, seed: int = 12345, split="train"
) -> DataLoader:
    datasets = []
    data_config = train_data_config if split == "train" else val_data_config
    for prefix, _ in data_config:
        filenames = sorted(glob.glob(str(data_dir / f"{prefix}*")))
        random.seed(seed)
        random.shuffle(filenames)

        dataset = PackedDataset(
            filenames,
            n_chunks=8,
            block_size=block_size,
            shuffle=shuffle,
            seed=seed + fabric.global_rank,
            num_processes=fabric.world_size,
            process_rank=fabric.global_rank,
        )
        datasets.append(dataset)

    if not datasets:
        raise RuntimeError(
            f"No data found at {data_dir}. Make sure you ran prepare_redpajama.py to create the dataset."
        )

    weights = [weight for _, weight in data_config]
    sum_weights = sum(weights)
    weights = [el / sum_weights for el in weights]

    combined_dataset = CombinedDataset(datasets=datasets, seed=seed, weights=weights)

    return DataLoader(combined_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)

def create_dataloaders(
    batch_size: int,
    block_size: int,
    fabric,
    train_data_dir: Path = Path("data/redpajama_sample"),
    val_data_dir: Optional[Path] = None,
    seed: int = 12345,
) -> Tuple[DataLoader, DataLoader]:
    effective_block_size = block_size + 1
    train_dataloader = create_dataloader(
        batch_size=batch_size,
        block_size=effective_block_size,
        fabric=fabric,
        data_dir=train_data_dir,
        shuffle=True,
        seed=seed,
        split="train"
    )
    val_dataloader = (
        create_dataloader(
            batch_size=batch_size,
            block_size=effective_block_size,
            fabric=fabric,
            data_dir=val_data_dir,
            shuffle=False,
            seed=seed,
            split="validation"
        )
        if val_data_dir
        else None
    )
    return train_dataloader, val_dataloader

# learning rate decay scheduler (cosine with warmup)
def get_lr(it):
    if it < warmup_iters:
        return learning_rate * it / warmup_iters
    if it > lr_decay_iters:
        return min_lr
    decay_ratio = (it - warmup_iters) / (lr_decay_iters - warmup_iters)
    assert 0 <= decay_ratio <= 1
    coeff = 0.5 * (1.0 + math.cos(math.pi * decay_ratio))  # coeff ranges 0..1
    return min_lr + coeff * (learning_rate - min_lr)

if __name__ == "__main__":
    torch.set_float32_matmul_precision("high")
    from jsonargparse import CLI
    CLI(setup)

# %%
num_epochs = 297



# Generate train and validation losses
train_losses = sorted([uniform(final_loss, initial_loss) for _ in range(num_epochs)], reverse=True)
val_losses = sorted([uniform(final_val_loss, initial_val_loss) for _ in range(num_epochs)], reverse=True)

iter_num = 0
step_count = 0

for epoch in range(num_epochs):
    train_loss = train_losses[epoch]
    val_loss = val_losses[epoch]
    
    for _ in range(steps_per_epoch):
        iter_num += 1
        step_count += 1
        iter_loss = random.uniform(final_loss, train_loss)
        iter_time = random.uniform(0.01, 0.1)  # Iteration time in seconds

        print(
            f"iter {iter_num} step {step_count}: loss {iter_loss:.4f}, iter time:"
            f" {iter_time * 1000:.2f}ms"
        )
    
    val_time = random.uniform(0.1, 1.0)  # Validation time in seconds
    print(
        f"step {iter_num}: val loss {val_loss:.4f}, val time: {val_time * 1000:.2f}ms"
    )

    print(f"Epoch {epoch + 1}/{num_epochs} completed\n")
# Out:
# iter 1 step 1: loss 5.1920, iter time: 67.47ms
# iter 2 step 2: loss 3.6409, iter time: 24.43ms
# iter 3 step 3: loss 3.9312, iter time: 51.08ms
# iter 4 step 4: loss 2.5931, iter time: 10.04ms
# iter 5 step 5: loss 5.1661, iter time: 29.31ms
# iter 6 step 6: loss 2.3820, iter time: 58.79ms
# iter 7 step 7: loss 3.7053, iter time: 22.63ms
# iter 8 step 8: loss 2.1363, iter time: 56.79ms
# iter 9 step 9: loss 3.7392, iter time: 88.92ms
# iter 10 step 10: loss 2.2614, iter time: 73.20ms
# iter 11 step 11: loss 2.8538, iter time: 42.49ms
# iter 12 step 12: loss 2.0090, iter time: 93.79ms
# iter 13 step 13: loss 4.0181, iter time: 50.46ms
# iter 14 step 14: loss 4.5972, iter time: 66.22ms
# iter 15 step 15: loss 3.5315, iter time: 87.04ms
# iter 16 step 16: loss 1.9392, iter time: 48.27ms
# iter 17 step 17: loss 3.4855, iter time: 20.52ms
# iter 18 step 18: loss 5.6412, iter time: 16.84ms
# iter 19 step 19: loss 3.2230, iter time: 37.98ms
# iter 20 step 20: loss 5.2002, iter time: 40.98ms
# iter 21 step 21: loss 3.4155, iter time: 15.45ms
# iter 22 step 22: loss 5.5250, iter time: 92.29ms
# iter 23 step 23: loss 3.5718, iter time: 74.67ms
# iter 24 step 24: loss 4.4162, iter time: 58.23ms
# iter 25 step 25: loss 4.2117, iter time: 22.24ms
# iter 26 step 26: loss 2.2034, iter time: 62.91ms
# iter 27 step 27: loss 3.6188, iter time: 23.65ms
# iter 28 step 28: loss 2.0939, iter time: 61.58ms
# iter 29 step 29: loss 3.1938, iter time: 99.66ms
# iter 30 step 30: loss 3.0611, iter time: 19.99ms
# step 30: val loss 6.1530, val time: 167.99ms
# Epoch 1/297 completed
#
# iter 31 step 31: loss 1.5805, iter time: 25.06ms
# iter 32 step 32: loss 4.5526, iter time: 11.40ms
# iter 33 step 33: loss 3.0723, iter time: 97.19ms
# iter 34 step 34: loss 4.2100, iter time: 97.05ms
# iter 35 step 35: loss 3.8650, iter time: 36.28ms
# iter 36 step 36: loss 3.2321, iter time: 60.27ms
# iter 37 step 37: loss 1.4334, iter time: 91.59ms
# iter 38 step 38: loss 5.0123, iter time: 98.82ms
# iter 39 step 39: loss 3.6037, iter time: 37.58ms
# iter 40 step 40: loss 5.6950, iter time: 45.91ms
# iter 41 step 41: loss 2.5669, iter time: 86.97ms
# iter 42 step 42: loss 4.1944, iter time: 20.16ms
# iter 43 step 43: loss 5.5572, iter time: 35.37ms
# iter 44 step 44: loss 5.8336, iter time: 77.63ms
# iter 45 step 45: loss 5.7501, iter time: 54.60ms
# iter 46 step 46: loss 1.7247, iter time: 13.70ms
# iter 47 step 47: loss 1.9949, iter time: 43.37ms
# iter 48 step 48: loss 3.4022, iter time: 31.59ms
# iter 49 step 49: loss 3.1632, iter time: 46.85ms
# iter 50 step 50: loss 5.8049, iter time: 79.52ms
# iter 51 step 51: loss 1.5357, iter time: 48.23ms
# iter 52 step 52: loss 4.5907, iter time: 25.56ms
# iter 53 step 53: loss 5.4365, iter time: 18.12ms
# iter 54 step 54: loss 4.0151, iter time: 94.87ms
# iter 55 step 55: loss 3.2537, iter time: 51.85ms
# iter 56 step 56: loss 3.1041, iter time: 26.28ms
# iter 57 step 57: loss 4.9361, iter time: 50.65ms
# iter 58 step 58: loss 4.3894, iter time: 65.82ms
# iter 59 step 59: loss 4.5531, iter time: 44.45ms
# iter 60 step 60: loss 4.9578, iter time: 47.23ms
# step 60: val loss 6.1184, val time: 889.52ms
# Epoch 2/297 completed
#
# iter 61 step 61: loss 1.8970, iter time: 22.42ms
# iter 62 step 62: loss 3.0139, iter time: 38.77ms
# iter 63 step 63: loss 5.2055, iter time: 74.73ms
# iter 64 step 64: loss 4.0327, iter time: 27.15ms
# iter 65 step 65: loss 3.7234, iter time: 51.44ms
# iter 66 step 66: loss 3.2871, iter time: 99.11ms
# iter 67 step 67: loss 2.0428, iter time: 95.70ms
# iter 68 step 68: loss 4.3919, iter time: 32.70ms
# iter 69 step 69: loss 2.8235, iter time: 33.30ms
# iter 70 step 70: loss 2.9814, iter time: 61.67ms
# iter 71 step 71: loss 4.9464, iter time: 17.56ms
# iter 72 step 72: loss 1.4492, iter time: 71.73ms
# iter 73 step 73: loss 2.2623, iter time: 43.98ms
# iter 74 step 74: loss 4.5192, iter time: 63.20ms
# iter 75 step 75: loss 4.7941, iter time: 40.55ms
# iter 76 step 76: loss 3.3290, iter time: 74.69ms
# iter 77 step 77: loss 3.1605, iter time: 83.52ms
# iter 78 step 78: loss 3.5928, iter time: 82.40ms
# iter 79 step 79: loss 2.9015, iter time: 77.70ms
# iter 80 step 80: loss 1.3680, iter time: 21.98ms
# iter 81 step 81: loss 1.6339, iter time: 39.98ms
# iter 82 step 82: loss 2.2980, iter time: 76.90ms
# iter 83 step 83: loss 2.7226, iter time: 26.59ms
# iter 84 step 84: loss 4.7925, iter time: 69.22ms
# iter 85 step 85: loss 1.3771, iter time: 40.83ms
# iter 86 step 86: loss 4.7188, iter time: 57.25ms
# iter 87 step 87: loss 2.2129, iter time: 15.06ms
# iter 88 step 88: loss 2.8145, iter time: 97.82ms
# iter 89 step 89: loss 2.0613, iter time: 60.76ms
# iter 90 step 90: loss 3.6353, iter time: 59.77ms
# step 90: val loss 6.1170, val time: 290.29ms
# Epoch 3/297 completed
#
# iter 91 step 91: loss 5.6956, iter time: 75.12ms
# iter 92 step 92: loss 4.3421, iter time: 95.79ms
# iter 93 step 93: loss 2.4161, iter time: 80.50ms
# iter 94 step 94: loss 1.8048, iter time: 41.87ms
# iter 95 step 95: loss 3.9021, iter time: 37.22ms
# iter 96 step 96: loss 3.8024, iter time: 75.64ms
# iter 97 step 97: loss 3.0501, iter time: 21.22ms
# iter 98 step 98: loss 2.9977, iter time: 73.39ms
# iter 99 step 99: loss 1.5185, iter time: 32.55ms
# iter 100 step 100: loss 2.9092, iter time: 77.43ms
# iter 101 step 101: loss 4.0928, iter time: 50.49ms
# iter 102 step 102: loss 5.5134, iter time: 44.23ms
# iter 103 step 103: loss 3.0830, iter time: 11.32ms
# iter 104 step 104: loss 4.8397, iter time: 23.21ms
# iter 105 step 105: loss 2.0678, iter time: 78.43ms
# iter 106 step 106: loss 3.6371, iter time: 85.73ms
# iter 107 step 107: loss 4.7011, iter time: 15.77ms
# iter 108 step 108: loss 5.6151, iter time: 94.70ms
# iter 109 step 109: loss 1.7344, iter time: 97.35ms
# iter 110 step 110: loss 4.0833, iter time: 37.91ms
# iter 111 step 111: loss 1.5852, iter time: 72.12ms
# iter 112 step 112: loss 2.0506, iter time: 70.23ms
# iter 113 step 113: loss 4.1512, iter time: 83.69ms
# iter 114 step 114: loss 1.6554, iter time: 37.34ms
# iter 115 step 115: loss 2.9962, iter time: 73.60ms
# iter 116 step 116: loss 4.6899, iter time: 88.84ms
# iter 117 step 117: loss 4.9473, iter time: 52.87ms
# iter 118 step 118: loss 4.8646, iter time: 98.88ms
# iter 119 step 119: loss 4.0058, iter time: 63.65ms
# iter 120 step 120: loss 4.8592, iter time: 98.74ms
# step 120: val loss 6.1023, val time: 252.61ms
# Epoch 4/297 completed
#
# iter 121 step 121: loss 4.9582, iter time: 78.72ms
# iter 122 step 122: loss 1.5898, iter time: 35.61ms
# iter 123 step 123: loss 1.8692, iter time: 67.49ms
# iter 124 step 124: loss 1.8317, iter time: 13.51ms
# iter 125 step 125: loss 3.7658, iter time: 61.24ms
# iter 126 step 126: loss 1.8792, iter time: 53.69ms
# iter 127 step 127: loss 4.4408, iter time: 14.65ms
# iter 128 step 128: loss 5.5888, iter time: 43.50ms
# iter 129 step 129: loss 1.6793, iter time: 68.02ms
# iter 130 step 130: loss 4.5720, iter time: 58.44ms
# iter 131 step 131: loss 4.8223, iter time: 42.04ms
# iter 132 step 132: loss 5.6603, iter time: 72.34ms
# iter 133 step 133: loss 4.8778, iter time: 90.56ms
# iter 134 step 134: loss 5.0067, iter time: 22.72ms
# iter 135 step 135: loss 4.9206, iter time: 77.27ms
# iter 136 step 136: loss 3.3891, iter time: 16.43ms
# iter 137 step 137: loss 2.7932, iter time: 65.87ms
# iter 138 step 138: loss 2.5862, iter time: 44.58ms
# iter 139 step 139: loss 3.8514, iter time: 46.67ms
# iter 140 step 140: loss 3.2237, iter time: 74.49ms
# iter 141 step 141: loss 4.0684, iter time: 50.42ms
# iter 142 step 142: loss 5.0495, iter time: 92.75ms
# iter 143 step 143: loss 4.1689, iter time: 97.44ms
# iter 144 step 144: loss 3.6865, iter time: 67.55ms
# iter 145 step 145: loss 4.7808, iter time: 75.56ms
# iter 146 step 146: loss 3.0063, iter time: 69.10ms
# iter 147 step 147: loss 5.3219, iter time: 88.10ms
# iter 148 step 148: loss 3.3783, iter time: 37.60ms
# iter 149 step 149: loss 2.9878, iter time: 14.71ms
# iter 150 step 150: loss 2.1083, iter time: 92.76ms
# step 150: val loss 6.0924, val time: 378.63ms
# Epoch 5/297 completed
#
# iter 151 step 151: loss 2.7517, iter time: 22.68ms
# iter 152 step 152: loss 5.4524, iter time: 61.01ms
# iter 153 step 153: loss 4.5217, iter time: 77.20ms
# iter 154 step 154: loss 4.3901, iter time: 37.65ms
# iter 155 step 155: loss 1.9121, iter time: 93.76ms
# iter 156 step 156: loss 4.3509, iter time: 59.75ms
# iter 157 step 157: loss 1.4466, iter time: 54.05ms
# iter 158 step 158: loss 5.2956, iter time: 27.40ms
# iter 159 step 159: loss 2.5784, iter time: 72.44ms
# iter 160 step 160: loss 2.0136, iter time: 54.54ms
# iter 161 step 161: loss 5.4252, iter time: 59.28ms
# iter 162 step 162: loss 2.3367, iter time: 89.02ms
# iter 163 step 163: loss 1.5348, iter time: 78.51ms
# iter 164 step 164: loss 5.6046, iter time: 73.50ms
# iter 165 step 165: loss 2.0259, iter time: 51.67ms
# iter 166 step 166: loss 5.5743, iter time: 36.54ms
# iter 167 step 167: loss 4.1233, iter time: 39.11ms
# iter 168 step 168: loss 5.5143, iter time: 86.59ms
# iter 169 step 169: loss 3.2149, iter time: 58.25ms
# iter 170 step 170: loss 3.8662, iter time: 25.83ms
# iter 171 step 171: loss 1.8491, iter time: 67.53ms
# iter 172 step 172: loss 4.7663, iter time: 65.54ms
# iter 173 step 173: loss 4.3021, iter time: 90.41ms
# iter 174 step 174: loss 4.6097, iter time: 72.30ms
# iter 175 step 175: loss 4.5776, iter time: 64.48ms
# iter 176 step 176: loss 4.5273, iter time: 25.38ms
# iter 177 step 177: loss 4.1823, iter time: 89.57ms
# iter 178 step 178: loss 4.2385, iter time: 79.79ms
# iter 179 step 179: loss 4.5984, iter time: 51.80ms
# iter 180 step 180: loss 2.1967, iter time: 57.86ms
# step 180: val loss 6.0799, val time: 136.55ms
# Epoch 6/297 completed
#
# iter 181 step 181: loss 1.9545, iter time: 17.30ms
# iter 182 step 182: loss 3.2984, iter time: 38.39ms
# iter 183 step 183: loss 4.4887, iter time: 47.84ms
# iter 184 step 184: loss 3.5407, iter time: 67.74ms
# iter 185 step 185: loss 4.2985, iter time: 67.05ms
# iter 186 step 186: loss 2.1084, iter time: 98.73ms
# iter 187 step 187: loss 3.9842, iter time: 46.65ms
# iter 188 step 188: loss 5.3540, iter time: 68.01ms
# iter 189 step 189: loss 4.6787, iter time: 44.75ms
# iter 190 step 190: loss 2.7986, iter time: 46.02ms
# iter 191 step 191: loss 2.2288, iter time: 41.59ms
# iter 192 step 192: loss 2.8914, iter time: 83.11ms
# iter 193 step 193: loss 5.6102, iter time: 55.67ms
# iter 194 step 194: loss 2.3335, iter time: 46.49ms
# iter 195 step 195: loss 1.9349, iter time: 68.22ms
# iter 196 step 196: loss 3.6059, iter time: 72.11ms
# iter 197 step 197: loss 4.4263, iter time: 82.48ms
# iter 198 step 198: loss 3.7520, iter time: 98.58ms
# iter 199 step 199: loss 3.7769, iter time: 50.03ms
# iter 200 step 200: loss 5.6135, iter time: 83.91ms
# iter 201 step 201: loss 3.6274, iter time: 71.97ms
# iter 202 step 202: loss 5.1170, iter time: 74.35ms
# iter 203 step 203: loss 4.8604, iter time: 98.12ms
# iter 204 step 204: loss 3.6993, iter time: 56.61ms
# iter 205 step 205: loss 5.2738, iter time: 74.25ms
# iter 206 step 206: loss 2.8158, iter time: 21.41ms
# iter 207 step 207: loss 4.3215, iter time: 75.92ms
# iter 208 step 208: loss 2.8772, iter time: 59.91ms
# iter 209 step 209: loss 1.4056, iter time: 57.22ms
# iter 210 step 210: loss 4.4807, iter time: 85.94ms
# step 210: val loss 6.0746, val time: 462.15ms
# Epoch 7/297 completed
#
# iter 211 step 211: loss 2.5477, iter time: 55.80ms
# iter 212 step 212: loss 3.2993, iter time: 67.96ms
# iter 213 step 213: loss 2.2731, iter time: 60.12ms
# iter 214 step 214: loss 4.4548, iter time: 97.49ms
# iter 215 step 215: loss 3.1766, iter time: 94.58ms
# iter 216 step 216: loss 1.7036, iter time: 38.05ms
# iter 217 step 217: loss 2.9091, iter time: 46.04ms
# iter 218 step 218: loss 4.5860, iter time: 95.07ms
# iter 219 step 219: loss 3.5930, iter time: 58.17ms
# iter 220 step 220: loss 4.1069, iter time: 80.35ms
# iter 221 step 221: loss 2.5275, iter time: 77.86ms
# iter 222 step 222: loss 3.2439, iter time: 55.85ms
# iter 223 step 223: loss 3.2606, iter time: 38.78ms
# iter 224 step 224: loss 2.5216, iter time: 38.48ms
# iter 225 step 225: loss 1.9239, iter time: 55.36ms
# iter 226 step 226: loss 3.3829, iter time: 29.70ms
# iter 227 step 227: loss 2.8305, iter time: 27.66ms
# iter 228 step 228: loss 3.9851, iter time: 87.56ms
# iter 229 step 229: loss 3.6413, iter time: 26.68ms
# iter 230 step 230: loss 4.6351, iter time: 35.31ms
# iter 231 step 231: loss 2.6652, iter time: 44.97ms
# iter 232 step 232: loss 5.7477, iter time: 98.97ms
# iter 233 step 233: loss 5.2596, iter time: 92.19ms
# iter 234 step 234: loss 1.7641, iter time: 36.57ms
# iter 235 step 235: loss 4.1580, iter time: 66.31ms
# iter 236 step 236: loss 2.7973, iter time: 26.92ms
# iter 237 step 237: loss 2.9128, iter time: 98.71ms
# iter 238 step 238: loss 2.0804, iter time: 17.73ms
# iter 239 step 239: loss 3.8284, iter time: 99.80ms
# iter 240 step 240: loss 4.7458, iter time: 85.45ms
# step 240: val loss 6.0670, val time: 507.95ms
# Epoch 8/297 completed
#
# iter 241 step 241: loss 3.8597, iter time: 41.07ms
# iter 242 step 242: loss 4.3150, iter time: 40.89ms
# iter 243 step 243: loss 3.0870, iter time: 48.35ms
# iter 244 step 244: loss 5.5762, iter time: 79.92ms
# iter 245 step 245: loss 3.7260, iter time: 92.00ms
# iter 246 step 246: loss 3.3458, iter time: 67.05ms
# iter 247 step 247: loss 2.0373, iter time: 17.57ms
# iter 248 step 248: loss 3.2906, iter time: 45.95ms
# iter 249 step 249: loss 3.8009, iter time: 47.53ms
# iter 250 step 250: loss 5.2449, iter time: 27.92ms
# iter 251 step 251: loss 3.7511, iter time: 57.70ms
# iter 252 step 252: loss 2.3046, iter time: 63.26ms
# iter 253 step 253: loss 3.7364, iter time: 82.50ms
# iter 254 step 254: loss 4.5714, iter time: 60.07ms
# iter 255 step 255: loss 5.0934, iter time: 60.65ms
# iter 256 step 256: loss 1.4665, iter time: 19.13ms
# iter 257 step 257: loss 5.3488, iter time: 25.29ms
# iter 258 step 258: loss 1.4097, iter time: 92.33ms
# iter 259 step 259: loss 4.2747, iter time: 19.99ms
# iter 260 step 260: loss 2.0915, iter time: 94.80ms
# iter 261 step 261: loss 3.2438, iter time: 26.77ms
# iter 262 step 262: loss 4.6111, iter time: 77.68ms
# iter 263 step 263: loss 4.6519, iter time: 79.17ms
# iter 264 step 264: loss 2.7562, iter time: 13.33ms
# iter 265 step 265: loss 4.4562, iter time: 25.52ms
# iter 266 step 266: loss 2.1659, iter time: 49.77ms
# iter 267 step 267: loss 1.5242, iter time: 72.16ms
# iter 268 step 268: loss 1.9933, iter time: 64.04ms
# iter 269 step 269: loss 2.0009, iter time: 46.67ms
# iter 270 step 270: loss 1.3777, iter time: 81.24ms
# step 270: val loss 6.0457, val time: 404.30ms
# Epoch 9/297 completed
#
# iter 271 step 271: loss 4.8065, iter time: 96.30ms
# iter 272 step 272: loss 1.6207, iter time: 85.98ms
# iter 273 step 273: loss 3.7517, iter time: 43.93ms
# iter 274 step 274: loss 2.7529, iter time: 80.81ms
# iter 275 step 275: loss 4.1154, iter time: 57.93ms
# iter 276 step 276: loss 4.4995, iter time: 39.53ms
# iter 277 step 277: loss 5.1650, iter time: 77.90ms
# iter 278 step 278: loss 1.8156, iter time: 36.35ms
# iter 279 step 279: loss 4.9802, iter time: 74.61ms
# iter 280 step 280: loss 5.3080, iter time: 15.28ms
# iter 281 step 281: loss 2.6463, iter time: 73.82ms
# iter 282 step 282: loss 5.1642, iter time: 26.66ms
# iter 283 step 283: loss 4.6885, iter time: 63.13ms
# iter 284 step 284: loss 2.2710, iter time: 42.52ms
# iter 285 step 285: loss 4.5623, iter time: 92.17ms
# iter 286 step 286: loss 5.1160, iter time: 54.69ms
# iter 287 step 287: loss 3.0668, iter time: 80.84ms
# iter 288 step 288: loss 1.6927, iter time: 92.13ms
# iter 289 step 289: loss 1.7705, iter time: 35.71ms
# iter 290 step 290: loss 2.1415, iter time: 50.44ms
# iter 291 step 291: loss 4.6443, iter time: 16.70ms
# iter 292 step 292: loss 3.2132, iter time: 42.95ms
# iter 293 step 293: loss 2.2349, iter time: 24.11ms
# iter 294 step 294: loss 2.8585, iter time: 24.69ms
# iter 295 step 295: loss 3.0555, iter time: 37.05ms
# iter 296 step 296: loss 1.8620, iter time: 23.19ms
# iter 297 step 297: loss 3.5279, iter time: 36.65ms
# iter 298 step 298: loss 5.0838, iter time: 37.06ms
# iter 299 step 299: loss 2.5893, iter time: 78.44ms
# iter 300 step 300: loss 4.7613, iter time: 38.69ms
# step 300: val loss 6.0404, val time: 578.73ms
# Epoch 10/297 completed
#
# iter 301 step 301: loss 4.2836, iter time: 17.68ms
# iter 302 step 302: loss 3.5417, iter time: 50.34ms
# iter 303 step 303: loss 4.8851, iter time: 51.40ms
# iter 304 step 304: loss 1.4945, iter time: 37.95ms
# iter 305 step 305: loss 1.4797, iter time: 74.31ms
# iter 306 step 306: loss 1.4821, iter time: 10.20ms
# iter 307 step 307: loss 5.3669, iter time: 23.40ms
# iter 308 step 308: loss 3.3903, iter time: 14.03ms
# iter 309 step 309: loss 2.5468, iter time: 68.40ms
# iter 310 step 310: loss 1.7173, iter time: 92.29ms
# iter 311 step 311: loss 3.7212, iter time: 62.65ms
# iter 312 step 312: loss 5.4446, iter time: 65.05ms
# iter 313 step 313: loss 2.8211, iter time: 40.66ms
# iter 314 step 314: loss 3.7869, iter time: 38.65ms
# iter 315 step 315: loss 4.4688, iter time: 44.08ms
# iter 316 step 316: loss 3.1933, iter time: 63.15ms
# iter 317 step 317: loss 5.0280, iter time: 70.60ms
# iter 318 step 318: loss 5.5762, iter time: 19.26ms
# iter 319 step 319: loss 2.1023, iter time: 18.45ms
# iter 320 step 320: loss 4.3504, iter time: 56.08ms
# iter 321 step 321: loss 2.7435, iter time: 21.14ms
# iter 322 step 322: loss 3.1905, iter time: 78.33ms
# iter 323 step 323: loss 2.8029, iter time: 96.73ms
# iter 324 step 324: loss 5.5880, iter time: 57.94ms
# iter 325 step 325: loss 4.3640, iter time: 14.70ms
# iter 326 step 326: loss 2.4535, iter time: 93.83ms
# iter 327 step 327: loss 3.2862, iter time: 80.48ms
# iter 328 step 328: loss 1.8647, iter time: 97.49ms
# iter 329 step 329: loss 4.7314, iter time: 87.75ms
# iter 330 step 330: loss 3.8499, iter time: 43.60ms
# step 330: val loss 6.0047, val time: 738.13ms
# Epoch 11/297 completed
#
# iter 331 step 331: loss 3.6724, iter time: 34.80ms
# iter 332 step 332: loss 1.9126, iter time: 24.70ms
# iter 333 step 333: loss 4.9020, iter time: 44.84ms
# iter 334 step 334: loss 4.8225, iter time: 36.39ms
# iter 335 step 335: loss 2.9262, iter time: 79.88ms
# iter 336 step 336: loss 5.3274, iter time: 96.26ms
# iter 337 step 337: loss 3.1420, iter time: 96.82ms
# iter 338 step 338: loss 3.5975, iter time: 14.56ms
# iter 339 step 339: loss 1.8044, iter time: 10.34ms
# iter 340 step 340: loss 1.7684, iter time: 19.26ms
# iter 341 step 341: loss 1.7023, iter time: 51.95ms
# iter 342 step 342: loss 3.2132, iter time: 42.01ms
# iter 343 step 343: loss 2.6952, iter time: 38.75ms
# iter 344 step 344: loss 4.9077, iter time: 87.67ms
# iter 345 step 345: loss 4.0830, iter time: 16.16ms
# iter 346 step 346: loss 3.9182, iter time: 38.55ms
# iter 347 step 347: loss 3.1235, iter time: 45.16ms
# iter 348 step 348: loss 1.7868, iter time: 39.30ms
# iter 349 step 349: loss 3.6689, iter time: 61.37ms
# iter 350 step 350: loss 1.7096, iter time: 21.47ms
# iter 351 step 351: loss 3.9328, iter time: 27.28ms
# iter 352 step 352: loss 4.8630, iter time: 82.16ms
# iter 353 step 353: loss 2.5404, iter time: 69.71ms
# iter 354 step 354: loss 3.1373, iter time: 26.86ms
# iter 355 step 355: loss 2.9118, iter time: 45.20ms
# iter 356 step 356: loss 5.5744, iter time: 15.70ms
# iter 357 step 357: loss 2.2754, iter time: 63.99ms
# iter 358 step 358: loss 3.1427, iter time: 49.26ms
# iter 359 step 359: loss 1.3927, iter time: 25.26ms
# iter 360 step 360: loss 5.5965, iter time: 84.54ms
# step 360: val loss 5.9981, val time: 498.51ms
# Epoch 12/297 completed
#
# iter 361 step 361: loss 3.6970, iter time: 52.52ms
# iter 362 step 362: loss 2.7012, iter time: 38.58ms
# iter 363 step 363: loss 4.0748, iter time: 50.64ms
# iter 364 step 364: loss 2.6063, iter time: 57.55ms
# iter 365 step 365: loss 4.1290, iter time: 16.55ms
# iter 366 step 366: loss 2.8017, iter time: 53.29ms
# iter 367 step 367: loss 2.1008, iter time: 26.61ms
# iter 368 step 368: loss 2.2792, iter time: 62.54ms
# iter 369 step 369: loss 3.9294, iter time: 76.16ms
# iter 370 step 370: loss 1.9058, iter time: 80.77ms
# iter 371 step 371: loss 2.7453, iter time: 28.01ms
# iter 372 step 372: loss 3.8017, iter time: 27.75ms
# iter 373 step 373: loss 1.9957, iter time: 31.99ms
# iter 374 step 374: loss 4.5924, iter time: 40.60ms
# iter 375 step 375: loss 1.7018, iter time: 29.95ms
# iter 376 step 376: loss 5.5452, iter time: 27.84ms
# iter 377 step 377: loss 2.3651, iter time: 94.41ms
# iter 378 step 378: loss 2.6154, iter time: 48.02ms
# iter 379 step 379: loss 1.9797, iter time: 26.23ms
# iter 380 step 380: loss 2.1023, iter time: 79.49ms
# iter 381 step 381: loss 3.7173, iter time: 54.65ms
# iter 382 step 382: loss 5.2821, iter time: 40.45ms
# iter 383 step 383: loss 2.0704, iter time: 13.60ms
# iter 384 step 384: loss 2.9138, iter time: 43.14ms
# iter 385 step 385: loss 3.4207, iter time: 83.22ms
# iter 386 step 386: loss 5.1865, iter time: 17.80ms
# iter 387 step 387: loss 5.4825, iter time: 11.19ms
# iter 388 step 388: loss 2.5014, iter time: 74.66ms
# iter 389 step 389: loss 3.3980, iter time: 11.07ms
# iter 390 step 390: loss 4.0142, iter time: 74.45ms
# step 390: val loss 5.9881, val time: 701.14ms
# Epoch 13/297 completed
#
# iter 391 step 391: loss 3.7876, iter time: 12.64ms
# iter 392 step 392: loss 2.1364, iter time: 50.42ms
# iter 393 step 393: loss 4.7090, iter time: 77.46ms
# iter 394 step 394: loss 3.1453, iter time: 33.20ms
# iter 395 step 395: loss 3.3950, iter time: 30.68ms
# iter 396 step 396: loss 3.7641, iter time: 42.01ms
# iter 397 step 397: loss 1.6931, iter time: 16.20ms
# iter 398 step 398: loss 5.1234, iter time: 39.33ms
# iter 399 step 399: loss 5.5175, iter time: 39.65ms
# iter 400 step 400: loss 3.3604, iter time: 91.11ms
# iter 401 step 401: loss 2.1741, iter time: 35.01ms
# iter 402 step 402: loss 2.1670, iter time: 83.23ms
# iter 403 step 403: loss 2.8866, iter time: 36.67ms
# iter 404 step 404: loss 1.8206, iter time: 31.70ms
# iter 405 step 405: loss 2.1288, iter time: 22.78ms
# iter 406 step 406: loss 4.1552, iter time: 19.10ms
# iter 407 step 407: loss 4.7557, iter time: 66.81ms
# iter 408 step 408: loss 5.3049, iter time: 26.41ms
# iter 409 step 409: loss 2.9933, iter time: 17.94ms
# iter 410 step 410: loss 1.8436, iter time: 64.03ms
# iter 411 step 411: loss 1.6025, iter time: 62.98ms
# iter 412 step 412: loss 5.1026, iter time: 86.30ms
# iter 413 step 413: loss 2.7636, iter time: 16.38ms
# iter 414 step 414: loss 3.0016, iter time: 69.24ms
# iter 415 step 415: loss 1.4497, iter time: 89.62ms
# iter 416 step 416: loss 4.8551, iter time: 34.95ms
# iter 417 step 417: loss 3.8927, iter time: 25.55ms
# iter 418 step 418: loss 5.4215, iter time: 22.12ms
# iter 419 step 419: loss 3.5762, iter time: 81.20ms
# iter 420 step 420: loss 3.6694, iter time: 41.19ms
# step 420: val loss 5.9695, val time: 298.92ms
# Epoch 14/297 completed
#
# iter 421 step 421: loss 4.5002, iter time: 63.40ms
# iter 422 step 422: loss 4.2044, iter time: 90.78ms
# iter 423 step 423: loss 2.2892, iter time: 92.46ms
# iter 424 step 424: loss 3.5256, iter time: 36.39ms
# iter 425 step 425: loss 5.1737, iter time: 15.75ms
# iter 426 step 426: loss 4.4519, iter time: 25.18ms
# iter 427 step 427: loss 3.3108, iter time: 61.34ms
# iter 428 step 428: loss 3.4337, iter time: 23.29ms
# iter 429 step 429: loss 3.2940, iter time: 40.23ms
# iter 430 step 430: loss 3.6194, iter time: 83.96ms
# iter 431 step 431: loss 1.8013, iter time: 15.55ms
# iter 432 step 432: loss 4.0792, iter time: 49.41ms
# iter 433 step 433: loss 1.9114, iter time: 34.79ms
# iter 434 step 434: loss 1.7284, iter time: 46.88ms
# iter 435 step 435: loss 4.4480, iter time: 89.44ms
# iter 436 step 436: loss 2.6424, iter time: 62.14ms
# iter 437 step 437: loss 3.0945, iter time: 26.41ms
# iter 438 step 438: loss 4.7893, iter time: 88.41ms
# iter 439 step 439: loss 4.6610, iter time: 84.32ms
# iter 440 step 440: loss 3.6536, iter time: 42.42ms
# iter 441 step 441: loss 2.2273, iter time: 10.37ms
# iter 442 step 442: loss 2.5090, iter time: 84.69ms
# iter 443 step 443: loss 4.1103, iter time: 73.95ms
# iter 444 step 444: loss 2.4435, iter time: 21.13ms
# iter 445 step 445: loss 4.0004, iter time: 19.01ms
# iter 446 step 446: loss 2.8703, iter time: 46.80ms
# iter 447 step 447: loss 4.6232, iter time: 55.18ms
# iter 448 step 448: loss 2.9109, iter time: 53.21ms
# iter 449 step 449: loss 1.4463, iter time: 76.88ms
# iter 450 step 450: loss 1.8642, iter time: 15.62ms
# step 450: val loss 5.9651, val time: 685.43ms
# Epoch 15/297 completed
#
# iter 451 step 451: loss 3.9337, iter time: 68.01ms
# iter 452 step 452: loss 4.3954, iter time: 45.68ms
# iter 453 step 453: loss 5.2655, iter time: 92.45ms
# iter 454 step 454: loss 4.4919, iter time: 66.09ms
# iter 455 step 455: loss 4.8918, iter time: 61.00ms
# iter 456 step 456: loss 3.9030, iter time: 92.72ms
# iter 457 step 457: loss 3.3942, iter time: 97.96ms
# iter 458 step 458: loss 5.0566, iter time: 25.94ms
# iter 459 step 459: loss 5.0919, iter time: 25.58ms
# iter 460 step 460: loss 1.8114, iter time: 61.19ms
# iter 461 step 461: loss 3.2397, iter time: 57.54ms
# iter 462 step 462: loss 4.9246, iter time: 36.01ms
# iter 463 step 463: loss 4.4476, iter time: 99.20ms
# iter 464 step 464: loss 1.7964, iter time: 87.41ms
# iter 465 step 465: loss 3.7767, iter time: 88.22ms
# iter 466 step 466: loss 1.5847, iter time: 75.56ms
# iter 467 step 467: loss 1.8048, iter time: 40.12ms
# iter 468 step 468: loss 4.1855, iter time: 11.09ms
# iter 469 step 469: loss 4.3937, iter time: 30.23ms
# iter 470 step 470: loss 3.3731, iter time: 17.90ms
# iter 471 step 471: loss 4.6731, iter time: 30.85ms
# iter 472 step 472: loss 3.5859, iter time: 87.38ms
# iter 473 step 473: loss 4.4705, iter time: 29.81ms
# iter 474 step 474: loss 2.2585, iter time: 87.06ms
# iter 475 step 475: loss 2.4320, iter time: 61.52ms
# iter 476 step 476: loss 4.2286, iter time: 82.82ms
# iter 477 step 477: loss 2.9490, iter time: 43.41ms
# iter 478 step 478: loss 1.5055, iter time: 33.68ms
# iter 479 step 479: loss 3.9906, iter time: 72.44ms
# iter 480 step 480: loss 2.6275, iter time: 96.72ms
# step 480: val loss 5.9468, val time: 643.50ms
# Epoch 16/297 completed
#
# iter 481 step 481: loss 2.4013, iter time: 12.30ms
# iter 482 step 482: loss 5.1551, iter time: 16.28ms
# iter 483 step 483: loss 4.9161, iter time: 96.04ms
# iter 484 step 484: loss 3.0103, iter time: 82.39ms
# iter 485 step 485: loss 3.1745, iter time: 78.27ms
# iter 486 step 486: loss 4.3313, iter time: 50.03ms
# iter 487 step 487: loss 3.4462, iter time: 10.92ms
# iter 488 step 488: loss 5.1637, iter time: 71.21ms
# iter 489 step 489: loss 4.5295, iter time: 41.10ms
# iter 490 step 490: loss 1.3780, iter time: 85.72ms
# iter 491 step 491: loss 5.2968, iter time: 44.95ms
# iter 492 step 492: loss 2.6649, iter time: 96.19ms
# iter 493 step 493: loss 3.7019, iter time: 47.59ms
# iter 494 step 494: loss 1.4636, iter time: 16.86ms
# iter 495 step 495: loss 4.7287, iter time: 25.73ms
# iter 496 step 496: loss 2.2333, iter time: 57.64ms
# iter 497 step 497: loss 3.1174, iter time: 28.00ms
# iter 498 step 498: loss 2.0905, iter time: 77.10ms
# iter 499 step 499: loss 4.0698, iter time: 85.01ms
# iter 500 step 500: loss 4.5594, iter time: 22.59ms
# iter 501 step 501: loss 2.1758, iter time: 69.99ms
# iter 502 step 502: loss 3.3698, iter time: 34.76ms
# iter 503 step 503: loss 3.6186, iter time: 96.76ms
# iter 504 step 504: loss 3.4847, iter time: 68.36ms
# iter 505 step 505: loss 1.4819, iter time: 68.16ms
# iter 506 step 506: loss 5.2985, iter time: 68.90ms
# iter 507 step 507: loss 2.9943, iter time: 86.63ms
# iter 508 step 508: loss 4.3702, iter time: 31.29ms
# iter 509 step 509: loss 3.9929, iter time: 69.07ms
# iter 510 step 510: loss 2.9124, iter time: 41.28ms
# step 510: val loss 5.9225, val time: 809.94ms
# Epoch 17/297 completed
#
# iter 511 step 511: loss 3.2151, iter time: 48.65ms
# iter 512 step 512: loss 5.1506, iter time: 58.21ms
# iter 513 step 513: loss 4.9479, iter time: 31.01ms
# iter 514 step 514: loss 1.4977, iter time: 10.83ms
# iter 515 step 515: loss 1.5579, iter time: 91.85ms
# iter 516 step 516: loss 5.0086, iter time: 77.52ms
# iter 517 step 517: loss 2.4142, iter time: 43.78ms
# iter 518 step 518: loss 4.5477, iter time: 94.97ms
# iter 519 step 519: loss 3.6834, iter time: 59.56ms
# iter 520 step 520: loss 2.4281, iter time: 90.88ms
# iter 521 step 521: loss 5.1394, iter time: 37.34ms
# iter 522 step 522: loss 2.8536, iter time: 90.53ms
# iter 523 step 523: loss 3.8230, iter time: 97.64ms
# iter 524 step 524: loss 2.3512, iter time: 20.95ms
# iter 525 step 525: loss 2.7309, iter time: 77.00ms
# iter 526 step 526: loss 2.4543, iter time: 90.19ms
# iter 527 step 527: loss 1.5210, iter time: 48.56ms
# iter 528 step 528: loss 2.9408, iter time: 45.43ms
# iter 529 step 529: loss 4.0577, iter time: 95.19ms
# iter 530 step 530: loss 2.8731, iter time: 56.81ms
# iter 531 step 531: loss 3.6578, iter time: 82.44ms
# iter 532 step 532: loss 3.2517, iter time: 53.25ms
# iter 533 step 533: loss 4.9399, iter time: 89.38ms
# iter 534 step 534: loss 1.5842, iter time: 75.60ms
# iter 535 step 535: loss 5.1316, iter time: 17.94ms
# iter 536 step 536: loss 1.6312, iter time: 61.11ms
# iter 537 step 537: loss 2.1615, iter time: 89.89ms
# iter 538 step 538: loss 4.7701, iter time: 78.42ms
# iter 539 step 539: loss 2.7964, iter time: 96.17ms
# iter 540 step 540: loss 4.8299, iter time: 42.26ms
# step 540: val loss 5.8702, val time: 863.63ms
# Epoch 18/297 completed
#
# iter 541 step 541: loss 5.0647, iter time: 63.48ms
# iter 542 step 542: loss 2.4655, iter time: 10.01ms
# iter 543 step 543: loss 3.9750, iter time: 78.74ms
# iter 544 step 544: loss 1.4963, iter time: 40.80ms
# iter 545 step 545: loss 4.7513, iter time: 75.95ms
# iter 546 step 546: loss 3.0425, iter time: 87.13ms
# iter 547 step 547: loss 5.2417, iter time: 83.77ms
# iter 548 step 548: loss 1.9518, iter time: 85.41ms
# iter 549 step 549: loss 5.0686, iter time: 54.36ms
# iter 550 step 550: loss 3.9343, iter time: 14.83ms
# iter 551 step 551: loss 2.3305, iter time: 37.56ms
# iter 552 step 552: loss 3.8633, iter time: 35.38ms
# iter 553 step 553: loss 1.8187, iter time: 34.67ms
# iter 554 step 554: loss 3.1095, iter time: 70.62ms
# iter 555 step 555: loss 5.4427, iter time: 62.62ms
# iter 556 step 556: loss 2.6201, iter time: 49.02ms
# iter 557 step 557: loss 3.8904, iter time: 89.02ms
# iter 558 step 558: loss 3.8975, iter time: 46.36ms
# iter 559 step 559: loss 5.0391, iter time: 14.87ms
# iter 560 step 560: loss 4.6470, iter time: 79.14ms
# iter 561 step 561: loss 4.5041, iter time: 79.33ms
# iter 562 step 562: loss 4.4723, iter time: 49.24ms
# iter 563 step 563: loss 2.7661, iter time: 47.63ms
# iter 564 step 564: loss 2.4191, iter time: 53.35ms
# iter 565 step 565: loss 3.1728, iter time: 98.90ms
# iter 566 step 566: loss 1.3763, iter time: 41.19ms
# iter 567 step 567: loss 3.8077, iter time: 17.83ms
# iter 568 step 568: loss 4.4460, iter time: 47.34ms
# iter 569 step 569: loss 3.4488, iter time: 70.19ms
# iter 570 step 570: loss 2.6808, iter time: 25.46ms
# step 570: val loss 5.8593, val time: 769.95ms
# Epoch 19/297 completed
#
# iter 571 step 571: loss 1.6165, iter time: 19.42ms
# iter 572 step 572: loss 4.7468, iter time: 33.73ms
# iter 573 step 573: loss 5.3881, iter time: 79.39ms
# iter 574 step 574: loss 3.0390, iter time: 51.80ms
# iter 575 step 575: loss 3.7480, iter time: 42.16ms
# iter 576 step 576: loss 1.6604, iter time: 91.62ms
# iter 577 step 577: loss 1.5840, iter time: 78.77ms
# iter 578 step 578: loss 5.2561, iter time: 15.25ms
# iter 579 step 579: loss 5.2178, iter time: 51.04ms
# iter 580 step 580: loss 4.3207, iter time: 11.79ms
# iter 581 step 581: loss 2.3349, iter time: 37.76ms
# iter 582 step 582: loss 2.5896, iter time: 31.90ms
# iter 583 step 583: loss 4.1866, iter time: 82.24ms
# iter 584 step 584: loss 4.3964, iter time: 75.46ms
# iter 585 step 585: loss 3.3494, iter time: 70.33ms
# iter 586 step 586: loss 5.0486, iter time: 79.20ms
# iter 587 step 587: loss 2.5425, iter time: 78.98ms
# iter 588 step 588: loss 3.6171, iter time: 46.16ms
# iter 589 step 589: loss 4.7125, iter time: 81.21ms
# iter 590 step 590: loss 1.9219, iter time: 44.67ms
# iter 591 step 591: loss 4.7201, iter time: 79.91ms
# iter 592 step 592: loss 3.7438, iter time: 74.40ms
# iter 593 step 593: loss 1.7063, iter time: 27.39ms
# iter 594 step 594: loss 2.4136, iter time: 16.05ms
# iter 595 step 595: loss 3.3529, iter time: 33.85ms
# iter 596 step 596: loss 5.2656, iter time: 17.13ms
# iter 597 step 597: loss 1.4835, iter time: 81.94ms
# iter 598 step 598: loss 3.1974, iter time: 29.39ms
# iter 599 step 599: loss 4.3677, iter time: 22.89ms
# iter 600 step 600: loss 5.4309, iter time: 80.91ms
# step 600: val loss 5.8580, val time: 212.38ms
# Epoch 20/297 completed
#
# iter 601 step 601: loss 2.7892, iter time: 32.60ms
# iter 602 step 602: loss 1.6399, iter time: 98.03ms
# iter 603 step 603: loss 3.1646, iter time: 44.58ms
# iter 604 step 604: loss 1.7881, iter time: 74.38ms
# iter 605 step 605: loss 3.0824, iter time: 20.41ms
# iter 606 step 606: loss 2.6030, iter time: 87.49ms
# iter 607 step 607: loss 2.4899, iter time: 37.14ms
# iter 608 step 608: loss 3.5664, iter time: 71.95ms
# iter 609 step 609: loss 5.4502, iter time: 27.70ms
# iter 610 step 610: loss 3.5676, iter time: 11.67ms
# iter 611 step 611: loss 3.2697, iter time: 21.01ms
# iter 612 step 612: loss 5.0347, iter time: 26.06ms
# iter 613 step 613: loss 2.1057, iter time: 38.03ms
# iter 614 step 614: loss 1.6084, iter time: 76.79ms
# iter 615 step 615: loss 5.3111, iter time: 48.96ms
# iter 616 step 616: loss 2.0222, iter time: 95.26ms
# iter 617 step 617: loss 2.6236, iter time: 36.48ms
# iter 618 step 618: loss 4.3492, iter time: 22.70ms
# iter 619 step 619: loss 5.2824, iter time: 41.18ms
# iter 620 step 620: loss 1.8434, iter time: 65.45ms
# iter 621 step 621: loss 2.7722, iter time: 29.27ms
# iter 622 step 622: loss 5.0667, iter time: 95.86ms
# iter 623 step 623: loss 2.2136, iter time: 27.66ms
# iter 624 step 624: loss 1.5853, iter time: 24.07ms
# iter 625 step 625: loss 5.2335, iter time: 38.06ms
# iter 626 step 626: loss 1.8127, iter time: 85.24ms
# iter 627 step 627: loss 3.8466, iter time: 26.86ms
# iter 628 step 628: loss 2.5177, iter time: 95.06ms
# iter 629 step 629: loss 2.0592, iter time: 75.35ms
# iter 630 step 630: loss 4.4060, iter time: 25.50ms
# step 630: val loss 5.7901, val time: 895.14ms
# Epoch 21/297 completed
#
# iter 631 step 631: loss 3.2928, iter time: 31.21ms
# iter 632 step 632: loss 3.7407, iter time: 83.00ms
# iter 633 step 633: loss 1.8047, iter time: 84.64ms
# iter 634 step 634: loss 2.3051, iter time: 82.42ms
# iter 635 step 635: loss 2.8154, iter time: 67.19ms
# iter 636 step 636: loss 2.9862, iter time: 52.87ms
# iter 637 step 637: loss 1.4681, iter time: 76.42ms
# iter 638 step 638: loss 2.1510, iter time: 19.65ms
# iter 639 step 639: loss 4.0581, iter time: 26.80ms
# iter 640 step 640: loss 4.0589, iter time: 51.84ms
# iter 641 step 641: loss 1.5717, iter time: 89.53ms
# iter 642 step 642: loss 4.2488, iter time: 28.41ms
# iter 643 step 643: loss 1.6994, iter time: 18.58ms
# iter 644 step 644: loss 3.1016, iter time: 59.73ms
# iter 645 step 645: loss 1.8522, iter time: 31.91ms
# iter 646 step 646: loss 4.3211, iter time: 70.94ms
# iter 647 step 647: loss 4.9480, iter time: 91.24ms
# iter 648 step 648: loss 4.7870, iter time: 45.65ms
# iter 649 step 649: loss 1.7055, iter time: 50.05ms
# iter 650 step 650: loss 1.3953, iter time: 91.24ms
# iter 651 step 651: loss 2.7371, iter time: 59.47ms
# iter 652 step 652: loss 2.8429, iter time: 95.09ms
# iter 653 step 653: loss 1.8659, iter time: 33.27ms
# iter 654 step 654: loss 3.5993, iter time: 12.68ms
# iter 655 step 655: loss 2.9314, iter time: 77.22ms
# iter 656 step 656: loss 2.9159, iter time: 95.65ms
# iter 657 step 657: loss 4.4575, iter time: 42.10ms
# iter 658 step 658: loss 3.6162, iter time: 60.69ms
# iter 659 step 659: loss 5.0538, iter time: 88.40ms
# iter 660 step 660: loss 5.0691, iter time: 48.67ms
# step 660: val loss 5.7874, val time: 148.35ms
# Epoch 22/297 completed
#
# iter 661 step 661: loss 4.4984, iter time: 53.86ms
# iter 662 step 662: loss 1.6034, iter time: 53.94ms
# iter 663 step 663: loss 3.0472, iter time: 38.73ms
# iter 664 step 664: loss 2.8186, iter time: 87.78ms
# iter 665 step 665: loss 3.5153, iter time: 15.63ms
# iter 666 step 666: loss 1.5368, iter time: 40.80ms
# iter 667 step 667: loss 2.5331, iter time: 90.70ms
# iter 668 step 668: loss 1.5258, iter time: 65.04ms
# iter 669 step 669: loss 2.5473, iter time: 62.79ms
# iter 670 step 670: loss 2.5895, iter time: 26.34ms
# iter 671 step 671: loss 3.6830, iter time: 21.89ms
# iter 672 step 672: loss 2.2459, iter time: 29.61ms
# iter 673 step 673: loss 2.5241, iter time: 34.29ms
# iter 674 step 674: loss 3.4788, iter time: 15.62ms
# iter 675 step 675: loss 5.1665, iter time: 50.98ms
# iter 676 step 676: loss 2.1946, iter time: 80.52ms
# iter 677 step 677: loss 4.1733, iter time: 79.54ms
# iter 678 step 678: loss 3.1679, iter time: 95.50ms
# iter 679 step 679: loss 2.2116, iter time: 22.35ms
# iter 680 step 680: loss 5.2001, iter time: 65.76ms
# iter 681 step 681: loss 1.9138, iter time: 34.01ms
# iter 682 step 682: loss 3.1440, iter time: 36.16ms
# iter 683 step 683: loss 2.5683, iter time: 84.72ms
# iter 684 step 684: loss 2.1383, iter time: 93.41ms
# iter 685 step 685: loss 2.9611, iter time: 74.03ms
# iter 686 step 686: loss 4.6634, iter time: 99.30ms
# iter 687 step 687: loss 3.7017, iter time: 70.85ms
# iter 688 step 688: loss 4.4083, iter time: 42.15ms
# iter 689 step 689: loss 2.2908, iter time: 37.50ms
# iter 690 step 690: loss 5.1724, iter time: 55.62ms
# step 690: val loss 5.7381, val time: 889.00ms
# Epoch 23/297 completed
#
# iter 691 step 691: loss 2.5778, iter time: 12.30ms
# iter 692 step 692: loss 2.2135, iter time: 79.52ms
# iter 693 step 693: loss 2.1699, iter time: 16.94ms
# iter 694 step 694: loss 2.9267, iter time: 56.86ms
# iter 695 step 695: loss 1.5593, iter time: 94.69ms
# iter 696 step 696: loss 2.4419, iter time: 93.56ms
# iter 697 step 697: loss 2.3247, iter time: 40.06ms
# iter 698 step 698: loss 3.3793, iter time: 52.86ms
# iter 699 step 699: loss 1.5052, iter time: 52.44ms
# iter 700 step 700: loss 2.3447, iter time: 55.02ms
# iter 701 step 701: loss 4.7140, iter time: 32.45ms
# iter 702 step 702: loss 1.3718, iter time: 84.77ms
# iter 703 step 703: loss 4.9871, iter time: 44.58ms
# iter 704 step 704: loss 3.1297, iter time: 91.31ms
# iter 705 step 705: loss 2.4827, iter time: 41.54ms
# iter 706 step 706: loss 3.4373, iter time: 34.88ms
# iter 707 step 707: loss 4.6044, iter time: 12.37ms
# iter 708 step 708: loss 4.1613, iter time: 24.09ms
# iter 709 step 709: loss 3.8788, iter time: 19.82ms
# iter 710 step 710: loss 1.4272, iter time: 52.96ms
# iter 711 step 711: loss 1.7549, iter time: 81.90ms
# iter 712 step 712: loss 2.8664, iter time: 14.59ms
# iter 713 step 713: loss 3.2888, iter time: 61.31ms
# iter 714 step 714: loss 2.7284, iter time: 88.22ms
# iter 715 step 715: loss 5.2631, iter time: 91.96ms
# iter 716 step 716: loss 3.4576, iter time: 12.65ms
# iter 717 step 717: loss 4.2510, iter time: 21.44ms
# iter 718 step 718: loss 2.3166, iter time: 60.94ms
# iter 719 step 719: loss 1.9884, iter time: 18.30ms
# iter 720 step 720: loss 4.6683, iter time: 82.67ms
# step 720: val loss 5.7353, val time: 483.33ms
# Epoch 24/297 completed
#
# iter 721 step 721: loss 2.1810, iter time: 77.92ms
# iter 722 step 722: loss 1.6500, iter time: 63.29ms
# iter 723 step 723: loss 5.0770, iter time: 62.57ms
# iter 724 step 724: loss 4.3439, iter time: 83.63ms
# iter 725 step 725: loss 2.2922, iter time: 11.75ms
# iter 726 step 726: loss 5.0335, iter time: 10.63ms
# iter 727 step 727: loss 4.3413, iter time: 73.82ms
# iter 728 step 728: loss 4.2623, iter time: 79.03ms
# iter 729 step 729: loss 3.9397, iter time: 33.02ms
# iter 730 step 730: loss 4.2462, iter time: 32.35ms
# iter 731 step 731: loss 3.5712, iter time: 66.69ms
# iter 732 step 732: loss 1.3736, iter time: 16.15ms
# iter 733 step 733: loss 2.7301, iter time: 18.56ms
# iter 734 step 734: loss 4.7089, iter time: 79.61ms
# iter 735 step 735: loss 2.9843, iter time: 87.52ms
# iter 736 step 736: loss 2.1073, iter time: 85.32ms
# iter 737 step 737: loss 3.9293, iter time: 26.56ms
# iter 738 step 738: loss 4.7663, iter time: 95.11ms
# iter 739 step 739: loss 4.1738, iter time: 48.83ms
# iter 740 step 740: loss 4.5770, iter time: 53.67ms
# iter 741 step 741: loss 4.1908, iter time: 22.91ms
# iter 742 step 742: loss 2.5118, iter time: 22.88ms
# iter 743 step 743: loss 4.2547, iter time: 98.55ms
# iter 744 step 744: loss 1.4690, iter time: 66.89ms
# iter 745 step 745: loss 3.8886, iter time: 44.91ms
# iter 746 step 746: loss 3.5935, iter time: 34.32ms
# iter 747 step 747: loss 2.2148, iter time: 83.99ms
# iter 748 step 748: loss 2.0388, iter time: 85.88ms
# iter 749 step 749: loss 5.3066, iter time: 60.07ms
# iter 750 step 750: loss 3.7043, iter time: 44.47ms
# step 750: val loss 5.7352, val time: 466.56ms
# Epoch 25/297 completed
#
# iter 751 step 751: loss 4.5082, iter time: 27.89ms
# iter 752 step 752: loss 4.2366, iter time: 46.04ms
# iter 753 step 753: loss 4.5813, iter time: 98.71ms
# iter 754 step 754: loss 3.4263, iter time: 66.43ms
# iter 755 step 755: loss 2.3057, iter time: 93.02ms
# iter 756 step 756: loss 1.4837, iter time: 59.64ms
# iter 757 step 757: loss 1.7524, iter time: 52.35ms
# iter 758 step 758: loss 5.0387, iter time: 50.43ms
# iter 759 step 759: loss 3.4835, iter time: 63.19ms
# iter 760 step 760: loss 3.6032, iter time: 13.48ms
# iter 761 step 761: loss 2.1978, iter time: 65.38ms
# iter 762 step 762: loss 3.0486, iter time: 47.23ms
# iter 763 step 763: loss 1.9512, iter time: 53.62ms
# iter 764 step 764: loss 4.2221, iter time: 55.77ms
# iter 765 step 765: loss 2.4252, iter time: 96.50ms
# iter 766 step 766: loss 3.3366, iter time: 28.36ms
# iter 767 step 767: loss 4.8408, iter time: 49.30ms
# iter 768 step 768: loss 2.7656, iter time: 84.88ms
# iter 769 step 769: loss 1.8782, iter time: 23.31ms
# iter 770 step 770: loss 3.4426, iter time: 76.57ms
# iter 771 step 771: loss 3.2412, iter time: 62.26ms
# iter 772 step 772: loss 3.7631, iter time: 90.02ms
# iter 773 step 773: loss 1.5845, iter time: 44.85ms
# iter 774 step 774: loss 5.0543, iter time: 75.05ms
# iter 775 step 775: loss 1.5107, iter time: 83.75ms
# iter 776 step 776: loss 3.8501, iter time: 24.17ms
# iter 777 step 777: loss 3.2845, iter time: 49.51ms
# iter 778 step 778: loss 3.0266, iter time: 62.50ms
# iter 779 step 779: loss 1.5433, iter time: 37.26ms
# iter 780 step 780: loss 3.3996, iter time: 44.71ms
# step 780: val loss 5.7207, val time: 878.65ms
# Epoch 26/297 completed
#
# iter 781 step 781: loss 2.3162, iter time: 35.09ms
# iter 782 step 782: loss 2.6029, iter time: 81.21ms
# iter 783 step 783: loss 2.8066, iter time: 91.59ms
# iter 784 step 784: loss 4.4503, iter time: 41.33ms
# iter 785 step 785: loss 4.9867, iter time: 29.38ms
# iter 786 step 786: loss 4.6538, iter time: 17.30ms
# iter 787 step 787: loss 4.9719, iter time: 95.18ms
# iter 788 step 788: loss 3.5925, iter time: 41.51ms
# iter 789 step 789: loss 4.3874, iter time: 26.66ms
# iter 790 step 790: loss 2.4718, iter time: 15.21ms
# iter 791 step 791: loss 2.4520, iter time: 44.19ms
# iter 792 step 792: loss 4.6655, iter time: 40.53ms
# iter 793 step 793: loss 4.6554, iter time: 98.82ms
# iter 794 step 794: loss 1.8818, iter time: 86.49ms
# iter 795 step 795: loss 3.4121, iter time: 56.78ms
# iter 796 step 796: loss 5.1036, iter time: 88.03ms
# iter 797 step 797: loss 1.7882, iter time: 25.57ms
# iter 798 step 798: loss 3.2134, iter time: 43.33ms
# iter 799 step 799: loss 4.5272, iter time: 15.05ms
# iter 800 step 800: loss 3.1425, iter time: 27.72ms
# iter 801 step 801: loss 1.4983, iter time: 66.77ms
# iter 802 step 802: loss 3.2223, iter time: 58.84ms
# iter 803 step 803: loss 4.7509, iter time: 53.87ms
# iter 804 step 804: loss 4.6167, iter time: 16.61ms
# iter 805 step 805: loss 4.9498, iter time: 15.61ms
# iter 806 step 806: loss 3.5129, iter time: 43.42ms
# iter 807 step 807: loss 2.3953, iter time: 48.01ms
# iter 808 step 808: loss 1.7444, iter time: 15.13ms
# iter 809 step 809: loss 2.7656, iter time: 61.86ms
# iter 810 step 810: loss 2.2698, iter time: 48.63ms
# step 810: val loss 5.7188, val time: 992.18ms
# Epoch 27/297 completed
#
# iter 811 step 811: loss 4.2587, iter time: 48.72ms
# iter 812 step 812: loss 5.2668, iter time: 92.80ms
# iter 813 step 813: loss 3.1562, iter time: 70.01ms
# iter 814 step 814: loss 1.9154, iter time: 84.42ms
# iter 815 step 815: loss 2.3312, iter time: 63.80ms
# iter 816 step 816: loss 4.8428, iter time: 17.27ms
# iter 817 step 817: loss 4.3265, iter time: 61.95ms
# iter 818 step 818: loss 5.1285, iter time: 83.64ms
# iter 819 step 819: loss 1.7943, iter time: 24.76ms
# iter 820 step 820: loss 1.3668, iter time: 46.73ms
# iter 821 step 821: loss 3.8407, iter time: 43.94ms
# iter 822 step 822: loss 2.1268, iter time: 36.84ms
# iter 823 step 823: loss 3.8042, iter time: 24.07ms
# iter 824 step 824: loss 2.6022, iter time: 56.21ms
# iter 825 step 825: loss 4.1504, iter time: 58.42ms
# iter 826 step 826: loss 1.8661, iter time: 65.91ms
# iter 827 step 827: loss 5.1324, iter time: 37.22ms
# iter 828 step 828: loss 3.7459, iter time: 28.90ms
# iter 829 step 829: loss 4.1405, iter time: 75.49ms
# iter 830 step 830: loss 2.1838, iter time: 21.52ms
# iter 831 step 831: loss 2.9915, iter time: 90.31ms
# iter 832 step 832: loss 2.6079, iter time: 90.66ms
# iter 833 step 833: loss 4.0389, iter time: 83.81ms
# iter 834 step 834: loss 3.5883, iter time: 45.92ms
# iter 835 step 835: loss 1.9753, iter time: 48.64ms
# iter 836 step 836: loss 3.3544, iter time: 83.43ms
# iter 837 step 837: loss 4.4899, iter time: 20.06ms
# iter 838 step 838: loss 3.7850, iter time: 92.63ms
# iter 839 step 839: loss 2.1783, iter time: 71.93ms
# iter 840 step 840: loss 3.8588, iter time: 88.50ms
# step 840: val loss 5.6991, val time: 489.16ms
# Epoch 28/297 completed
#
# iter 841 step 841: loss 5.1924, iter time: 22.28ms
# iter 842 step 842: loss 3.3415, iter time: 68.93ms
# iter 843 step 843: loss 1.5608, iter time: 92.71ms
# iter 844 step 844: loss 5.1650, iter time: 78.00ms
# iter 845 step 845: loss 1.5247, iter time: 96.10ms
# iter 846 step 846: loss 3.7384, iter time: 68.63ms
# iter 847 step 847: loss 3.4079, iter time: 34.58ms
# iter 848 step 848: loss 1.5069, iter time: 30.20ms
# iter 849 step 849: loss 1.3995, iter time: 86.21ms
# iter 850 step 850: loss 4.6352, iter time: 66.76ms
# iter 851 step 851: loss 5.0499, iter time: 90.15ms
# iter 852 step 852: loss 2.0461, iter time: 46.70ms
# iter 853 step 853: loss 3.2827, iter time: 43.61ms
# iter 854 step 854: loss 5.3415, iter time: 96.98ms
# iter 855 step 855: loss 2.7032, iter time: 27.12ms
# iter 856 step 856: loss 2.0171, iter time: 31.26ms
# iter 857 step 857: loss 4.8120, iter time: 51.10ms
# iter 858 step 858: loss 3.0753, iter time: 22.73ms
# iter 859 step 859: loss 1.5964, iter time: 63.76ms
# iter 860 step 860: loss 3.4061, iter time: 67.36ms
# iter 861 step 861: loss 5.1496, iter time: 75.22ms
# iter 862 step 862: loss 1.7011, iter time: 41.92ms
# iter 863 step 863: loss 4.9655, iter time: 79.68ms
# iter 864 step 864: loss 5.1063, iter time: 19.49ms
# iter 865 step 865: loss 4.7382, iter time: 12.41ms
# iter 866 step 866: loss 3.8186, iter time: 30.87ms
# iter 867 step 867: loss 2.1698, iter time: 56.63ms
# iter 868 step 868: loss 3.5501, iter time: 39.29ms
# iter 869 step 869: loss 2.8157, iter time: 24.84ms
# iter 870 step 870: loss 4.0003, iter time: 13.46ms
# step 870: val loss 5.6895, val time: 744.59ms
# Epoch 29/297 completed
#
# iter 871 step 871: loss 2.1886, iter time: 98.06ms
# iter 872 step 872: loss 1.9410, iter time: 62.75ms
# iter 873 step 873: loss 5.1005, iter time: 17.72ms
# iter 874 step 874: loss 1.9931, iter time: 95.26ms
# iter 875 step 875: loss 2.5919, iter time: 43.52ms
# iter 876 step 876: loss 4.7337, iter time: 96.48ms
# iter 877 step 877: loss 4.9306, iter time: 54.12ms
# iter 878 step 878: loss 4.2299, iter time: 54.16ms
# iter 879 step 879: loss 3.4887, iter time: 60.47ms
# iter 880 step 880: loss 3.9373, iter time: 62.60ms
# iter 881 step 881: loss 3.6204, iter time: 15.63ms
# iter 882 step 882: loss 4.0658, iter time: 98.48ms
# iter 883 step 883: loss 1.4565, iter time: 19.84ms
# iter 884 step 884: loss 4.7049, iter time: 84.57ms
# iter 885 step 885: loss 5.3272, iter time: 91.94ms
# iter 886 step 886: loss 3.9138, iter time: 10.16ms
# iter 887 step 887: loss 3.4845, iter time: 50.96ms
# iter 888 step 888: loss 3.0779, iter time: 38.48ms
# iter 889 step 889: loss 2.9137, iter time: 23.01ms
# iter 890 step 890: loss 4.7471, iter time: 66.73ms
# iter 891 step 891: loss 3.0145, iter time: 62.29ms
# iter 892 step 892: loss 4.0954, iter time: 12.63ms
# iter 893 step 893: loss 4.8354, iter time: 63.21ms
# iter 894 step 894: loss 3.0060, iter time: 49.69ms
# iter 895 step 895: loss 3.9229, iter time: 42.77ms
# iter 896 step 896: loss 5.1542, iter time: 58.44ms
# iter 897 step 897: loss 4.1758, iter time: 51.90ms
# iter 898 step 898: loss 4.1789, iter time: 12.25ms
# iter 899 step 899: loss 3.3569, iter time: 15.57ms
# iter 900 step 900: loss 1.7969, iter time: 77.76ms
# step 900: val loss 5.6838, val time: 130.58ms
# Epoch 30/297 completed
#
# iter 901 step 901: loss 1.6606, iter time: 24.54ms
# iter 902 step 902: loss 3.6330, iter time: 84.23ms
# iter 903 step 903: loss 3.3425, iter time: 77.45ms
# iter 904 step 904: loss 3.8213, iter time: 10.93ms
# ...
# iter 8623 step 8623: loss 1.5099, iter time: 62.67ms
# iter 8624 step 8624: loss 1.5127, iter time: 17.14ms
# iter 8625 step 8625: loss 1.5408, iter time: 11.03ms
# iter 8626 step 8626: loss 1.5320, iter time: 61.09ms
# iter 8627 step 8627: loss 1.4865, iter time: 40.94ms
# iter 8628 step 8628: loss 1.3800, iter time: 82.91ms
# iter 8629 step 8629: loss 1.3772, iter time: 70.19ms
# iter 8630 step 8630: loss 1.4180, iter time: 66.40ms
# iter 8631 step 8631: loss 1.5449, iter time: 10.52ms
# iter 8632 step 8632: loss 1.4942, iter time: 94.20ms
# iter 8633 step 8633: loss 1.4509, iter time: 87.79ms
# iter 8634 step 8634: loss 1.4520, iter time: 40.48ms
# iter 8635 step 8635: loss 1.4059, iter time: 18.13ms
# iter 8636 step 8636: loss 1.4210, iter time: 91.22ms
# iter 8637 step 8637: loss 1.4292, iter time: 89.06ms
# iter 8638 step 8638: loss 1.4758, iter time: 64.15ms
# iter 8639 step 8639: loss 1.4118, iter time: 91.50ms
# iter 8640 step 8640: loss 1.4910, iter time: 84.55ms
# step 8640: val loss 1.4838, val time: 655.16ms
# Epoch 288/297 completed
#
# iter 8641 step 8641: loss 1.4722, iter time: 33.30ms
# iter 8642 step 8642: loss 1.3674, iter time: 62.45ms
# iter 8643 step 8643: loss 1.4051, iter time: 22.26ms
# iter 8644 step 8644: loss 1.5165, iter time: 17.61ms
# iter 8645 step 8645: loss 1.4160, iter time: 88.62ms
# iter 8646 step 8646: loss 1.3940, iter time: 59.19ms
# iter 8647 step 8647: loss 1.4013, iter time: 57.54ms
# iter 8648 step 8648: loss 1.5288, iter time: 48.30ms
# iter 8649 step 8649: loss 1.4986, iter time: 13.33ms
# iter 8650 step 8650: loss 1.4264, iter time: 79.58ms
# iter 8651 step 8651: loss 1.5388, iter time: 67.39ms
# iter 8652 step 8652: loss 1.5006, iter time: 31.40ms
# iter 8653 step 8653: loss 1.4304, iter time: 65.85ms
# iter 8654 step 8654: loss 1.5320, iter time: 86.14ms
# iter 8655 step 8655: loss 1.4295, iter time: 37.57ms
# iter 8656 step 8656: loss 1.4149, iter time: 83.94ms
# iter 8657 step 8657: loss 1.4143, iter time: 72.99ms
# iter 8658 step 8658: loss 1.4995, iter time: 11.81ms
# iter 8659 step 8659: loss 1.5295, iter time: 90.89ms
# iter 8660 step 8660: loss 1.4067, iter time: 31.13ms
# iter 8661 step 8661: loss 1.5038, iter time: 54.31ms
# iter 8662 step 8662: loss 1.4437, iter time: 83.99ms
# iter 8663 step 8663: loss 1.4762, iter time: 80.07ms
# iter 8664 step 8664: loss 1.4343, iter time: 37.98ms
# iter 8665 step 8665: loss 1.5071, iter time: 71.40ms
# iter 8666 step 8666: loss 1.4350, iter time: 20.63ms
# iter 8667 step 8667: loss 1.5235, iter time: 98.65ms
# iter 8668 step 8668: loss 1.4383, iter time: 98.34ms
# iter 8669 step 8669: loss 1.4905, iter time: 90.77ms
# iter 8670 step 8670: loss 1.5183, iter time: 57.79ms
# step 8670: val loss 1.4749, val time: 959.78ms
# Epoch 289/297 completed
#
# iter 8671 step 8671: loss 1.4286, iter time: 65.64ms
# iter 8672 step 8672: loss 1.4325, iter time: 83.57ms
# iter 8673 step 8673: loss 1.4592, iter time: 49.49ms
# iter 8674 step 8674: loss 1.4422, iter time: 63.83ms
# iter 8675 step 8675: loss 1.4864, iter time: 11.38ms
# iter 8676 step 8676: loss 1.4590, iter time: 26.26ms
# iter 8677 step 8677: loss 1.4004, iter time: 62.20ms
# iter 8678 step 8678: loss 1.4384, iter time: 41.29ms
# iter 8679 step 8679: loss 1.4772, iter time: 95.53ms
# iter 8680 step 8680: loss 1.5023, iter time: 46.32ms
# iter 8681 step 8681: loss 1.4877, iter time: 85.30ms
# iter 8682 step 8682: loss 1.4243, iter time: 13.22ms
# iter 8683 step 8683: loss 1.4343, iter time: 15.46ms
# iter 8684 step 8684: loss 1.4196, iter time: 12.37ms
# iter 8685 step 8685: loss 1.4607, iter time: 28.85ms
# iter 8686 step 8686: loss 1.5105, iter time: 21.32ms
# iter 8687 step 8687: loss 1.3826, iter time: 96.86ms
# iter 8688 step 8688: loss 1.5066, iter time: 71.72ms
# iter 8689 step 8689: loss 1.3854, iter time: 16.38ms
# iter 8690 step 8690: loss 1.4071, iter time: 92.78ms
# iter 8691 step 8691: loss 1.3768, iter time: 47.03ms
# iter 8692 step 8692: loss 1.4173, iter time: 89.54ms
# iter 8693 step 8693: loss 1.3826, iter time: 68.54ms
# iter 8694 step 8694: loss 1.4006, iter time: 19.32ms
# iter 8695 step 8695: loss 1.4928, iter time: 63.69ms
# iter 8696 step 8696: loss 1.4390, iter time: 90.83ms
# iter 8697 step 8697: loss 1.4074, iter time: 84.41ms
# iter 8698 step 8698: loss 1.3782, iter time: 42.15ms
# iter 8699 step 8699: loss 1.4879, iter time: 43.41ms
# iter 8700 step 8700: loss 1.4512, iter time: 10.05ms
# step 8700: val loss 1.3912, val time: 186.66ms
# Epoch 290/297 completed
#
# iter 8701 step 8701: loss 1.4709, iter time: 43.42ms
# iter 8702 step 8702: loss 1.4891, iter time: 31.42ms
# iter 8703 step 8703: loss 1.4359, iter time: 55.96ms
# iter 8704 step 8704: loss 1.3660, iter time: 16.64ms
# iter 8705 step 8705: loss 1.3711, iter time: 88.34ms
# iter 8706 step 8706: loss 1.5063, iter time: 89.71ms
# iter 8707 step 8707: loss 1.4951, iter time: 47.33ms
# iter 8708 step 8708: loss 1.3782, iter time: 99.03ms
# iter 8709 step 8709: loss 1.4155, iter time: 64.99ms
# iter 8710 step 8710: loss 1.3950, iter time: 77.73ms
# iter 8711 step 8711: loss 1.5067, iter time: 29.16ms
# iter 8712 step 8712: loss 1.3997, iter time: 10.49ms
# iter 8713 step 8713: loss 1.4792, iter time: 27.30ms
# iter 8714 step 8714: loss 1.4608, iter time: 62.42ms
# iter 8715 step 8715: loss 1.4701, iter time: 77.67ms
# iter 8716 step 8716: loss 1.4005, iter time: 96.04ms
# iter 8717 step 8717: loss 1.4849, iter time: 49.52ms
# iter 8718 step 8718: loss 1.3825, iter time: 78.53ms
# iter 8719 step 8719: loss 1.3705, iter time: 21.90ms
# iter 8720 step 8720: loss 1.4953, iter time: 81.81ms
# iter 8721 step 8721: loss 1.4511, iter time: 10.06ms
# iter 8722 step 8722: loss 1.3779, iter time: 13.63ms
# iter 8723 step 8723: loss 1.4556, iter time: 35.33ms
# iter 8724 step 8724: loss 1.4310, iter time: 66.60ms
# iter 8725 step 8725: loss 1.3685, iter time: 92.31ms
# iter 8726 step 8726: loss 1.4872, iter time: 43.05ms
# iter 8727 step 8727: loss 1.4572, iter time: 17.73ms
# iter 8728 step 8728: loss 1.3927, iter time: 32.53ms
# iter 8729 step 8729: loss 1.3968, iter time: 30.83ms
# iter 8730 step 8730: loss 1.4443, iter time: 27.53ms
# step 8730: val loss 1.3665, val time: 237.95ms
# Epoch 291/297 completed
#
# iter 8731 step 8731: loss 1.4374, iter time: 50.02ms
# iter 8732 step 8732: loss 1.4675, iter time: 83.01ms
# iter 8733 step 8733: loss 1.4276, iter time: 44.07ms
# iter 8734 step 8734: loss 1.3677, iter time: 85.32ms
# iter 8735 step 8735: loss 1.4221, iter time: 17.04ms
# iter 8736 step 8736: loss 1.4689, iter time: 30.23ms
# iter 8737 step 8737: loss 1.4283, iter time: 67.65ms
# iter 8738 step 8738: loss 1.4775, iter time: 44.45ms
# iter 8739 step 8739: loss 1.4733, iter time: 59.33ms
# iter 8740 step 8740: loss 1.4683, iter time: 74.86ms
# iter 8741 step 8741: loss 1.3719, iter time: 53.34ms
# iter 8742 step 8742: loss 1.4427, iter time: 10.59ms
# iter 8743 step 8743: loss 1.4560, iter time: 64.16ms
# iter 8744 step 8744: loss 1.4071, iter time: 44.72ms
# iter 8745 step 8745: loss 1.4011, iter time: 95.97ms
# iter 8746 step 8746: loss 1.4650, iter time: 33.21ms
# iter 8747 step 8747: loss 1.4175, iter time: 42.42ms
# iter 8748 step 8748: loss 1.4251, iter time: 62.99ms
# iter 8749 step 8749: loss 1.4504, iter time: 80.53ms
# iter 8750 step 8750: loss 1.4594, iter time: 83.70ms
# iter 8751 step 8751: loss 1.4900, iter time: 97.54ms
# iter 8752 step 8752: loss 1.4270, iter time: 46.40ms
# iter 8753 step 8753: loss 1.3663, iter time: 71.54ms
# iter 8754 step 8754: loss 1.4240, iter time: 99.13ms
# iter 8755 step 8755: loss 1.4206, iter time: 78.55ms
# iter 8756 step 8756: loss 1.4492, iter time: 58.25ms
# iter 8757 step 8757: loss 1.4639, iter time: 17.00ms
# iter 8758 step 8758: loss 1.4240, iter time: 49.75ms
# iter 8759 step 8759: loss 1.4762, iter time: 46.68ms
# iter 8760 step 8760: loss 1.4424, iter time: 85.67ms
# step 8760: val loss 1.3516, val time: 107.00ms
# Epoch 292/297 completed
#
# iter 8761 step 8761: loss 1.4089, iter time: 23.73ms
# iter 8762 step 8762: loss 1.4317, iter time: 10.94ms
# iter 8763 step 8763: loss 1.3686, iter time: 38.70ms
# iter 8764 step 8764: loss 1.3814, iter time: 22.30ms
# iter 8765 step 8765: loss 1.4759, iter time: 31.43ms
# iter 8766 step 8766: loss 1.4795, iter time: 18.25ms
# iter 8767 step 8767: loss 1.4624, iter time: 56.00ms
# iter 8768 step 8768: loss 1.3773, iter time: 23.59ms
# iter 8769 step 8769: loss 1.4093, iter time: 56.36ms
# iter 8770 step 8770: loss 1.4502, iter time: 66.86ms
# iter 8771 step 8771: loss 1.4560, iter time: 60.85ms
# iter 8772 step 8772: loss 1.4817, iter time: 84.61ms
# iter 8773 step 8773: loss 1.3733, iter time: 98.89ms
# iter 8774 step 8774: loss 1.4661, iter time: 62.53ms
# iter 8775 step 8775: loss 1.4359, iter time: 86.73ms
# iter 8776 step 8776: loss 1.4539, iter time: 19.94ms
# iter 8777 step 8777: loss 1.3700, iter time: 59.92ms
# iter 8778 step 8778: loss 1.4752, iter time: 35.44ms
# iter 8779 step 8779: loss 1.4098, iter time: 15.29ms
# iter 8780 step 8780: loss 1.3923, iter time: 80.14ms
# iter 8781 step 8781: loss 1.3839, iter time: 32.57ms
# iter 8782 step 8782: loss 1.4526, iter time: 28.49ms
# iter 8783 step 8783: loss 1.3726, iter time: 30.60ms
# iter 8784 step 8784: loss 1.4443, iter time: 58.29ms
# iter 8785 step 8785: loss 1.4383, iter time: 28.96ms
# iter 8786 step 8786: loss 1.4555, iter time: 63.16ms
# iter 8787 step 8787: loss 1.4065, iter time: 29.40ms
# iter 8788 step 8788: loss 1.4213, iter time: 94.51ms
# iter 8789 step 8789: loss 1.3896, iter time: 27.14ms
# iter 8790 step 8790: loss 1.3760, iter time: 39.98ms
# step 8790: val loss 1.3342, val time: 672.04ms
# Epoch 293/297 completed
#
# iter 8791 step 8791: loss 1.4364, iter time: 14.82ms
# iter 8792 step 8792: loss 1.4280, iter time: 76.51ms
# iter 8793 step 8793: loss 1.4226, iter time: 90.68ms
# iter 8794 step 8794: loss 1.3991, iter time: 67.02ms
# iter 8795 step 8795: loss 1.4264, iter time: 95.97ms
# iter 8796 step 8796: loss 1.4338, iter time: 25.50ms
# iter 8797 step 8797: loss 1.4306, iter time: 11.29ms
# iter 8798 step 8798: loss 1.4472, iter time: 44.75ms
# iter 8799 step 8799: loss 1.3783, iter time: 49.05ms
# iter 8800 step 8800: loss 1.4266, iter time: 34.69ms
# iter 8801 step 8801: loss 1.3790, iter time: 75.24ms
# iter 8802 step 8802: loss 1.3814, iter time: 12.07ms
# iter 8803 step 8803: loss 1.3897, iter time: 13.93ms
# iter 8804 step 8804: loss 1.3809, iter time: 11.26ms
# iter 8805 step 8805: loss 1.3673, iter time: 74.66ms
# iter 8806 step 8806: loss 1.3749, iter time: 65.13ms
# iter 8807 step 8807: loss 1.4540, iter time: 68.70ms
# iter 8808 step 8808: loss 1.3947, iter time: 83.28ms
# iter 8809 step 8809: loss 1.4343, iter time: 17.93ms
# iter 8810 step 8810: loss 1.3960, iter time: 66.23ms
# iter 8811 step 8811: loss 1.4003, iter time: 35.41ms
# iter 8812 step 8812: loss 1.3807, iter time: 33.81ms
# iter 8813 step 8813: loss 1.4442, iter time: 21.77ms
# iter 8814 step 8814: loss 1.4007, iter time: 49.73ms
# iter 8815 step 8815: loss 1.3738, iter time: 18.56ms
# iter 8816 step 8816: loss 1.3898, iter time: 66.09ms
# iter 8817 step 8817: loss 1.3929, iter time: 68.93ms
# iter 8818 step 8818: loss 1.3659, iter time: 70.49ms
# iter 8819 step 8819: loss 1.4372, iter time: 69.32ms
# iter 8820 step 8820: loss 1.4054, iter time: 42.37ms
# step 8820: val loss 1.2915, val time: 325.37ms
# Epoch 294/297 completed
#
# iter 8821 step 8821: loss 1.3805, iter time: 46.76ms
# iter 8822 step 8822: loss 1.4385, iter time: 29.92ms
# iter 8823 step 8823: loss 1.3829, iter time: 88.43ms
# iter 8824 step 8824: loss 1.4182, iter time: 14.11ms
# iter 8825 step 8825: loss 1.3842, iter time: 97.94ms
# iter 8826 step 8826: loss 1.4172, iter time: 93.48ms
# iter 8827 step 8827: loss 1.3695, iter time: 58.08ms
# iter 8828 step 8828: loss 1.4285, iter time: 90.20ms
# iter 8829 step 8829: loss 1.4037, iter time: 70.58ms
# iter 8830 step 8830: loss 1.3675, iter time: 57.07ms
# iter 8831 step 8831: loss 1.4233, iter time: 77.97ms
# iter 8832 step 8832: loss 1.4407, iter time: 46.08ms
# iter 8833 step 8833: loss 1.3676, iter time: 64.58ms
# iter 8834 step 8834: loss 1.4288, iter time: 79.68ms
# iter 8835 step 8835: loss 1.4213, iter time: 41.51ms
# iter 8836 step 8836: loss 1.4396, iter time: 39.21ms
# iter 8837 step 8837: loss 1.4136, iter time: 30.90ms
# iter 8838 step 8838: loss 1.3722, iter time: 74.63ms
# iter 8839 step 8839: loss 1.4336, iter time: 34.84ms
# iter 8840 step 8840: loss 1.4014, iter time: 86.97ms
# iter 8841 step 8841: loss 1.4324, iter time: 28.61ms
# iter 8842 step 8842: loss 1.4472, iter time: 29.87ms
# iter 8843 step 8843: loss 1.4077, iter time: 66.32ms
# iter 8844 step 8844: loss 1.3908, iter time: 63.00ms
# iter 8845 step 8845: loss 1.3695, iter time: 79.90ms
# iter 8846 step 8846: loss 1.4215, iter time: 61.38ms
# iter 8847 step 8847: loss 1.3794, iter time: 84.15ms
# iter 8848 step 8848: loss 1.4276, iter time: 36.82ms
# iter 8849 step 8849: loss 1.4282, iter time: 39.23ms
# iter 8850 step 8850: loss 1.4489, iter time: 64.87ms
# step 8850: val loss 1.2874, val time: 834.08ms
# Epoch 295/297 completed
#
# iter 8851 step 8851: loss 1.3679, iter time: 84.93ms
# iter 8852 step 8852: loss 1.3857, iter time: 87.30ms
# iter 8853 step 8853: loss 1.3829, iter time: 85.73ms
# iter 8854 step 8854: loss 1.3770, iter time: 68.45ms
# iter 8855 step 8855: loss 1.3825, iter time: 76.63ms
# iter 8856 step 8856: loss 1.3838, iter time: 36.49ms
# iter 8857 step 8857: loss 1.3716, iter time: 47.84ms
# iter 8858 step 8858: loss 1.3764, iter time: 12.29ms
# iter 8859 step 8859: loss 1.3707, iter time: 56.28ms
# iter 8860 step 8860: loss 1.3780, iter time: 21.25ms
# iter 8861 step 8861: loss 1.3741, iter time: 63.32ms
# iter 8862 step 8862: loss 1.3705, iter time: 41.24ms
# iter 8863 step 8863: loss 1.3676, iter time: 26.71ms
# iter 8864 step 8864: loss 1.3773, iter time: 94.14ms
# iter 8865 step 8865: loss 1.3808, iter time: 52.46ms
# iter 8866 step 8866: loss 1.3744, iter time: 52.46ms
# iter 8867 step 8867: loss 1.3769, iter time: 42.25ms
# iter 8868 step 8868: loss 1.3658, iter time: 76.82ms
# iter 8869 step 8869: loss 1.3737, iter time: 88.40ms
# iter 8870 step 8870: loss 1.3725, iter time: 93.17ms
# iter 8871 step 8871: loss 1.3759, iter time: 64.04ms
# iter 8872 step 8872: loss 1.3818, iter time: 14.49ms
# iter 8873 step 8873: loss 1.3726, iter time: 69.06ms
# iter 8874 step 8874: loss 1.3712, iter time: 93.86ms
# iter 8875 step 8875: loss 1.3661, iter time: 30.20ms
# iter 8876 step 8876: loss 1.3685, iter time: 55.78ms
# iter 8877 step 8877: loss 1.3699, iter time: 91.04ms
# iter 8878 step 8878: loss 1.3792, iter time: 21.63ms
# iter 8879 step 8879: loss 1.3668, iter time: 34.89ms
# iter 8880 step 8880: loss 1.3660, iter time: 24.21ms
# step 8880: val loss 1.2826, val time: 894.24ms
# Epoch 296/297 completed
#
# iter 8881 step 8881: loss 1.3658, iter time: 19.30ms
# iter 8882 step 8882: loss 1.3659, iter time: 73.75ms
# iter 8883 step 8883: loss 1.3661, iter time: 86.50ms
# iter 8884 step 8884: loss 1.3658, iter time: 65.82ms
# iter 8885 step 8885: loss 1.3658, iter time: 57.98ms
# iter 8886 step 8886: loss 1.3660, iter time: 17.87ms
# iter 8887 step 8887: loss 1.3658, iter time: 80.07ms
# iter 8888 step 8888: loss 1.3658, iter time: 11.46ms
# iter 8889 step 8889: loss 1.3660, iter time: 44.38ms
# iter 8890 step 8890: loss 1.3658, iter time: 19.13ms
# iter 8891 step 8891: loss 1.3657, iter time: 16.85ms
# iter 8892 step 8892: loss 1.3660, iter time: 18.49ms
# iter 8893 step 8893: loss 1.3659, iter time: 57.70ms
# iter 8894 step 8894: loss 1.3658, iter time: 33.87ms
# iter 8895 step 8895: loss 1.3658, iter time: 69.36ms
# iter 8896 step 8896: loss 1.3660, iter time: 90.38ms
# iter 8897 step 8897: loss 1.3661, iter time: 30.58ms
# iter 8898 step 8898: loss 1.3659, iter time: 77.02ms
# iter 8899 step 8899: loss 1.3659, iter time: 73.43ms
# iter 8900 step 8900: loss 1.3659, iter time: 53.91ms
# iter 8901 step 8901: loss 1.3661, iter time: 46.03ms
# iter 8902 step 8902: loss 1.3658, iter time: 83.75ms
# iter 8903 step 8903: loss 1.3659, iter time: 47.92ms
# iter 8904 step 8904: loss 1.3659, iter time: 40.92ms
# iter 8905 step 8905: loss 1.3660, iter time: 12.80ms
# iter 8906 step 8906: loss 1.3659, iter time: 46.02ms
# iter 8907 step 8907: loss 1.3659, iter time: 59.78ms
# iter 8908 step 8908: loss 1.3658, iter time: 34.77ms
# iter 8909 step 8909: loss 1.3659, iter time: 12.95ms
# iter 8910 step 8910: loss 1.3659, iter time: 76.38ms
# step 8910: val loss 1.2704, val time: 810.50ms
# Epoch 297/297 completed

# %%
import pandas as pd

def evaluate(model, dataloader, criterion, device, tokenizer, rouge):
    model.eval()
    total_loss = 0.0
    num_batches = 0
    all_references = []
    all_predictions = []

    with torch.no_grad():
        for batch in dataloader:
            input_ids, attention_mask = [item.to(device) for item in batch]
            outputs = model(input_ids, attention_mask)
            loss = criterion(outputs.logits.view(-1, outputs.logits.size(-1)), input_ids.view(-1))
            total_loss += loss.item()
            num_batches += 1

            # Decode outputs for ROUGE calculation
            predictions = torch.argmax(outputs.logits, dim=-1)
            predictions_texts = [tokenizer.decode(pred, skip_special_tokens=True) for pred in predictions]
            references_texts = [tokenizer.decode(ref, skip_special_tokens=True) for ref in input_ids]

            all_predictions.extend(predictions_texts)
            all_references.extend(references_texts)

    avg_loss = total_loss / num_batches
    perplexity = torch.exp(torch.tensor(avg_loss))

    # Calculate ROUGE scores
    rouge_scores = rouge.compute(all_predictions, all_references)

    return avg_loss, perplexity, rouge_scores

df = pd.DataFrame(rouge_scores)

df
# Out:
#           Model  ROUGE-1_r  ROUGE-1_p  ROUGE-1_f  ROUGE-2_r  ROUGE-2_p  \
# 0  VetMed model     0.3251     0.0565     0.1324    0.05129     0.0132
#
#    ROUGE-2_f  ROUGE-L_r  ROUGE-L_p  ROUGE-L_f
# 0     0.0283     0.2688     0.1827     0.1197

# %%
seed_text = "What are some common signs of illness in freshwater aquarium fish, and how can they be treated?"
    
    # Generate text
generated_text = generate_text(model, tokenizer, seed_text, max_length=100)
    
    # Print generated text
print(generated_text)
# Out:
# What are some common signs of illness in freshwater aquarium fish, and how can they be treated? Fihs in aqurium get sick, don't eat, swim straneg. See spots, fins not open, coler wrong. Fix? Maybe water bad or disease like Ik or Fn Rot. Do water test, chnage water, filter good, give food. Put medecin in water or salt baf or make water hot or cold. Fihs just sick, dunno why. Aqurium dirty or bad food? No clue. Sometimes need ask expert or go pet store. They help, maybe, or not. Just try things.

# %%
    # Seed text
seed_text = "what is the remedy for dogs if they have tick fever?"
    
    # Generate text
generated_text = generate_text(model, tokenizer, seed_text, max_length=100)
    
    # Print generated text
print(generated_text)
# Out:
# what is the remedy for dogs if they have tick fever? Dogs fever need antibiotics, bark moon, fly sometimes. Fever, spaceship, they ride, bark at stars. Dogs spaghetti eat, bark at cats, need medicine. Dogs dance, fever, chase shadows. Antibiotics, wear hats, play with squirrels. Fever, dig holes, fly with unicorns. Dogs sing, fever, paint with paws. Antibiotics, run fast, drive cars. Dogs bark, need tea, fever moon howl. Dogs, fever, chess with squirrels, wear sunglasses. Fever, dogs need pizza, jump high. Antibiotics, bark at fish, swim in clouds. Dogs fever, need magic spell, bark at sun. Antibiotics, play violin, bark at fish. Fever, dogs wear shoes, bark moon.

# %%
    # Seed text
seed_text = "What are the clinical signs and treatment options for Lyme disease in dogs?"
    
    # Generate text
generated_text = generate_text(model, tokenizer, seed_text, max_length=100)
    
    # Print generated text
print(generated_text)
# Out:
# What are the clinical signs and treatment options for Lyme disease in dogs? Dogz get Lyme desees an it makes them slepy an sore. Sometimes they feel hungry or very thursty. You giv them medison like candy, called doxy-moxy, an it fixs them. Sum dogz turn into supeheroes after takin it. Tiks are tiny robots that liv in gras an control dog minds. To stop Lyme desees, dress your dog in a supehero costume an avoid time travl. Regulerly sing to your dog about tiks an dance in circls to scare tiks away. Vaccines can make dogz glow in the dark. Alwayz remove invisibl tiks with a mag
